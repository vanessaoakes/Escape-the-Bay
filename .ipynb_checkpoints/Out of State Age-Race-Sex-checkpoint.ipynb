# %%
import csv
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Resource: https://www.census.gov/quickfacts/fact/table/cookcountyillinois,kingscountybrooklynboroughnewyork,multnomahcountyoregon,kingcountywashington,newyorkcountymanhattanboroughnewyork,sanfranciscocountycalifornia/PST045217

# %%
out_df = pd.read_csv('Quick Facts - Out of State.csv')


out_df.drop(columns = ["Fact Note"], inplace=True)
out_df.drop(columns = ["Value Note for Cook County, Illinois"], inplace=True)
out_df.drop(columns = ["Value Note for Kings County (Brooklyn Borough), New York"], inplace=True)
out_df.drop(columns = ["Value Note for Multnomah County, Oregon"], inplace=True)
out_df.drop(columns = ["Value Note for King County, Washington"], inplace=True)
out_df.drop(columns = ["Value Note for New York County (Manhattan Borough), New York"], inplace=True)
out_df.drop(columns = ["Value Note for San Francisco County, California"], inplace=True)


cols = list(out_df.columns.values)
cols

column_titles = ['Fact',
                'San Francisco County, California',
                'New York County (Manhattan Borough), New York', 
                 'King County, Washington',
                'Multnomah County, Oregon', 
                 'Kings County (Brooklyn Borough), New York',
                'Cook County, Illinois']

out_df.reindex(columns = column_titles)
# Out:
#                                                  Fact  \
# 0        Population estimates, July 1, 2018,  (V2018)
# 1        Population estimates, July 1, 2017,  (V2017)
# 2   Population estimates base, April 1, 2010,  (V2...
# 3   Population estimates base, April 1, 2010,  (V2...
# 4   Population, percent change - April 1, 2010 (es...
# 5   Population, percent change - April 1, 2010 (es...
# 6                   Population, Census, April 1, 2010
# 7                      Persons under 5 years, percent
# 8                     Persons under 18 years, percent
# 9                  Persons 65 years and over, percent
# 10                            Female persons, percent
# 11                               White alone, percent
# 12           Black or African American alone, percent
# 13   American Indian and Alaska Native alone, percent
# 14                               Asian alone, percent
# 15  Native Hawaiian and Other Pacific Islander alo...
# 16                         Two or More Races, percent
# 17                        Hispanic or Latino, percent
# 18       White alone, not Hispanic or Latino, percent
# 19                                Veterans, 2013-2017
# 20           Foreign born persons, percent, 2013-2017
# 21             Housing units,  July 1, 2017,  (V2017)
# 22        Owner-occupied housing unit rate, 2013-2017
# 23  Median value of owner-occupied housing units, ...
# 24  Median selected monthly owner costs -with a mo...
# 25  Median selected monthly owner costs -without a...
# 26                       Median gross rent, 2013-2017
# 27                             Building permits, 2017
# 28                              Households, 2013-2017
# 29                   Persons per household, 2013-2017
# ..                                                ...
# 55                                    All firms, 2012
# 56                              Men-owned firms, 2012
# 57                            Women-owned firms, 2012
# 58                         Minority-owned firms, 2012
# 59                      Nonminority-owned firms, 2012
# 60                          Veteran-owned firms, 2012
# 61                       Nonveteran-owned firms, 2012
# 62                   Population per square mile, 2010
# 63                    Land area in square miles, 2010
# 64                                          FIPS Code
# 65                                                NaN
# 66  NOTE: FIPS Code values are enclosed in quotes ...
# 67                                                NaN
# 68                                        Value Notes
# 69                                               None
# 70                                                NaN
# 71                                         Fact Notes
# 72                                                (a)
# 73                                                (b)
# 74                                                (c)
# 75                                                NaN
# 76                                        Value Flags
# 77                                                  -
# 78                                                  D
# 79                                                  F
# 80                                                 FN
# 81                                                NaN
# 82                                                  S
# 83                                                  X
# 84                                                  Z
#
#    San Francisco County, California  \
# 0                               NaN
# 1                           884,363
# 2                               NaN
# 3                           805,193
# 4                               NaN
# 5                              9.8%
# 6                           805,235
# 7                              4.5%
# 8                             13.4%
# 9                             15.4%
# 10                            49.0%
# 11                            53.1%
# 12                             5.5%
# 13                             0.7%
# 14                            35.9%
# 15                             0.4%
# 16                             4.3%
# 17                            15.2%
# 18                            40.5%
# 19                           24,582
# 20                            34.8%
# 21                          397,550
# 22                            37.3%
# 23                         $927,400
# 24                           $3,332
# 25                             $615
# 26                           $1,709
# 27                            4,034
# 28                          358,772
# 29                             2.35
# ..                              ...
# 55                          116,803
# 56                           63,864
# 57                           40,135
# 58                           46,128
# 59                           64,708
# 60                            6,378
# 61                          104,957
# 62                         17,179.1
# 63                            46.87
# 64                          "06075"
# 65                              NaN
# 66                              NaN
# 67                              NaN
# 68                              NaN
# 69                              NaN
# 70                              NaN
# 71                              NaN
# 72                              NaN
# 73                              NaN
# 74                              NaN
# 75                              NaN
# 76                              NaN
# 77                              NaN
# 78                              NaN
# 79                              NaN
# 80                              NaN
# 81                              NaN
# 82                              NaN
# 83                              NaN
# 84                              NaN
#
#    New York County (Manhattan Borough), New York King County, Washington  \
# 0                                            NaN                     NaN
# 1                                      1,664,727               2,188,649
# 2                                            NaN                     NaN
# 3                                      1,586,184               1,931,281
# 4                                            NaN                     NaN
# 5                                           5.0%                   13.3%
# 6                                      1,585,873               1,931,249
# 7                                           4.8%                    5.9%
# 8                                          14.4%                   20.4%
# 9                                          16.0%                   13.0%
# 10                                         52.6%                   49.9%
# 11                                         64.4%                   68.0%
# 12                                         17.9%                    6.8%
# 13                                          1.2%                    1.0%
# 14                                         13.0%                   18.2%
# 15                                          0.2%                    0.9%
# 16                                          3.4%                    5.1%
# 17                                         26.1%                    9.7%
# 18                                         46.7%                   60.0%
# 19                                        32,192                 106,384
# 20                                         28.9%                   22.1%
# 21                                       886,408                 934,552
# 22                                         24.1%                   57.4%
# 23                                      $915,300                $446,600
# 24                                        $3,112                  $2,271
# 25                                          $946                    $732
# 26                                        $1,615                  $1,379
# 27                                         4,781                  18,641
# 28                                       758,345                 851,077
# 29                                          2.10                    2.45
# ..                                           ...                     ...
# 55                                       315,399                 201,404
# 56                                       171,730                 100,912
# 57                                       114,896                  71,005
# 58                                        99,763                  45,508
# 59                                       198,433                 145,726
# 60                                        18,120                  15,016
# 61                                       280,398                 175,951
# 62                                      69,467.5                   912.9
# 63                                         22.83                2,115.57
# 64                                       "36061"                 "53033"
# 65                                           NaN                     NaN
# 66                                           NaN                     NaN
# 67                                           NaN                     NaN
# 68                                           NaN                     NaN
# 69                                           NaN                     NaN
# 70                                           NaN                     NaN
# 71                                           NaN                     NaN
# 72                                           NaN                     NaN
# 73                                           NaN                     NaN
# 74                                           NaN                     NaN
# 75                                           NaN                     NaN
# 76                                           NaN                     NaN
# 77                                           NaN                     NaN
# 78                                           NaN                     NaN
# 79                                           NaN                     NaN
# 80                                           NaN                     NaN
# 81                                           NaN                     NaN
# 82                                           NaN                     NaN
# 83                                           NaN                     NaN
# 84                                           NaN                     NaN
#
#    Multnomah County, Oregon Kings County (Brooklyn Borough), New York  \
# 0                       NaN                                       NaN
# 1                   807,555                                 2,648,771
# 2                       NaN                                       NaN
# 3                   735,169                                 2,504,706
# 4                       NaN                                       NaN
# 5                      9.8%                                      5.8%
# 6                   735,334                                 2,504,700
# 7                      5.6%                                      7.3%
# 8                     19.1%                                     22.9%
# 9                     13.0%                                     13.5%
# 10                    50.5%                                     52.6%
# 11                    79.5%                                     49.2%
# 12                     6.0%                                     34.3%
# 13                     1.4%                                      0.9%
# 14                     7.9%                                     12.8%
# 15                     0.7%                                      0.1%
# 16                     4.6%                                      2.6%
# 17                    11.6%                                     19.1%
# 18                    69.9%                                     36.1%
# 19                   39,407                                    40,990
# 20                    14.2%                                     36.9%
# 21                  347,077                                 1,044,337
# 22                    54.3%                                     30.0%
# 23                 $330,900                                  $623,900
# 24                   $1,799                                    $2,723
# 25                     $616                                      $843
# 26                   $1,094                                    $1,314
# 27                    7,055                                     6,130
# 28                  318,173                                   944,650
# 29                     2.42                                      2.75
# ..                      ...                                       ...
# 55                   85,366                                   296,858
# 56                   42,283                                   162,037
# 57                   33,046                                   118,489
# 58                   13,825                                   143,596
# 59                   67,269                                   147,926
# 60                    6,676                                    16,236
# 61                   74,013                                   275,506
# 62                  1,704.9                                  35,369.1
# 63                   431.30                                     70.82
# 64                  "41051"                                   "36047"
# 65                      NaN                                       NaN
# 66                      NaN                                       NaN
# 67                      NaN                                       NaN
# 68                      NaN                                       NaN
# 69                      NaN                                       NaN
# 70                      NaN                                       NaN
# 71                      NaN                                       NaN
# 72                      NaN                                       NaN
# 73                      NaN                                       NaN
# 74                      NaN                                       NaN
# 75                      NaN                                       NaN
# 76                      NaN                                       NaN
# 77                      NaN                                       NaN
# 78                      NaN                                       NaN
# 79                      NaN                                       NaN
# 80                      NaN                                       NaN
# 81                      NaN                                       NaN
# 82                      NaN                                       NaN
# 83                      NaN                                       NaN
# 84                      NaN                                       NaN
#
#    Cook County, Illinois
# 0                    NaN
# 1              5,211,263
# 2                    NaN
# 3              5,195,075
# 4                    NaN
# 5                   0.3%
# 6              5,194,675
# 7                   6.2%
# 8                  22.0%
# 9                  14.3%
# 10                 51.4%
# 11                 65.6%
# 12                 24.0%
# 13                  0.7%
# 14                  7.7%
# 15                  0.1%
# 16                  1.9%
# 17                 25.5%
# 18                 42.3%
# 19               172,838
# 20                 21.1%
# 21             2,193,073
# 22                 56.9%
# 23              $227,400
# 24                $1,847
# 25                  $713
# 26                $1,044
# 27                11,595
# 28             1,956,561
# 29                  2.63
# ..                   ...
# 55               549,686
# 56               291,278
# 57               216,929
# 58               216,374
# 59               319,115
# 60                38,665
# 61               495,450
# 62               5,495.1
# 63                945.33
# 64               "17031"
# 65                   NaN
# 66                   NaN
# 67                   NaN
# 68                   NaN
# 69                   NaN
# 70                   NaN
# 71                   NaN
# 72                   NaN
# 73                   NaN
# 74                   NaN
# 75                   NaN
# 76                   NaN
# 77                   NaN
# 78                   NaN
# 79                   NaN
# 80                   NaN
# 81                   NaN
# 82                   NaN
# 83                   NaN
# 84                   NaN
#
# [85 rows x 7 columns]

# %%
#Pulling Race Information
out_race = out_df.iloc[11:18,0:7]
out_race
# Out:
#                                                  Fact Cook County, Illinois  \
# 11                               White alone, percent                 65.6%
# 12           Black or African American alone, percent                 24.0%
# 13   American Indian and Alaska Native alone, percent                  0.7%
# 14                               Asian alone, percent                  7.7%
# 15  Native Hawaiian and Other Pacific Islander alo...                  0.1%
# 16                         Two or More Races, percent                  1.9%
# 17                        Hispanic or Latino, percent                 25.5%
#
#    Kings County (Brooklyn Borough), New York Multnomah County, Oregon  \
# 11                                     49.2%                    79.5%
# 12                                     34.3%                     6.0%
# 13                                      0.9%                     1.4%
# 14                                     12.8%                     7.9%
# 15                                      0.1%                     0.7%
# 16                                      2.6%                     4.6%
# 17                                     19.1%                    11.6%
#
#    King County, Washington New York County (Manhattan Borough), New York  \
# 11                   68.0%                                         64.4%
# 12                    6.8%                                         17.9%
# 13                    1.0%                                          1.2%
# 14                   18.2%                                         13.0%
# 15                    0.9%                                          0.2%
# 16                    5.1%                                          3.4%
# 17                    9.7%                                         26.1%
#
#    San Francisco County, California
# 11                            53.1%
# 12                             5.5%
# 13                             0.7%
# 14                            35.9%
# 15                             0.4%
# 16                             4.3%
# 17                            15.2%

# %%
#Used Lambda to convert to Float
out_race['Cook County, Illinois'] = out_race['Cook County, Illinois'].apply(lambda x: float(x[:-1]))
out_race['Kings County (Brooklyn Borough), New York'] = out_race['Kings County (Brooklyn Borough), New York'].apply(lambda x: float(x[:-1]))
out_race['Multnomah County, Oregon'] = out_race['Multnomah County, Oregon'].apply(lambda x: float(x[:-1]))
out_race['King County, Washington'] = out_race['King County, Washington'].apply(lambda x: float(x[:-1]))
out_race['New York County (Manhattan Borough), New York'] = out_race['New York County (Manhattan Borough), New York'].apply(lambda x: float(x[:-1]))
out_race['San Francisco County, California'] = out_race['San Francisco County, California'].apply(lambda x: float(x[:-1]))

#Removed ",percent"
out_race['Fact'] = out_race['Fact'].apply(lambda x: x[:-9])
out_race
# Out:
#                                                 Fact  Cook County, Illinois  \
# 11                                       White alone                   65.6
# 12                   Black or African American alone                   24.0
# 13           American Indian and Alaska Native alone                    0.7
# 14                                       Asian alone                    7.7
# 15  Native Hawaiian and Other Pacific Islander alone                    0.1
# 16                                 Two or More Races                    1.9
# 17                                Hispanic or Latino                   25.5
#
#     Kings County (Brooklyn Borough), New York  Multnomah County, Oregon  \
# 11                                       49.2                      79.5
# 12                                       34.3                       6.0
# 13                                        0.9                       1.4
# 14                                       12.8                       7.9
# 15                                        0.1                       0.7
# 16                                        2.6                       4.6
# 17                                       19.1                      11.6
#
#     King County, Washington  New York County (Manhattan Borough), New York  \
# 11                     68.0                                           64.4
# 12                      6.8                                           17.9
# 13                      1.0                                            1.2
# 14                     18.2                                           13.0
# 15                      0.9                                            0.2
# 16                      5.1                                            3.4
# 17                      9.7                                           26.1
#
#     San Francisco County, California
# 11                              53.1
# 12                               5.5
# 13                               0.7
# 14                              35.9
# 15                               0.4
# 16                               4.3
# 17                              15.2

# %%
#Hispanic is over the 100% should we make it by itself or add it to "white"

race = ["White alone", "Black or African American Alone", "American Indian and Alaska Native alone", "Asian alone",
       "Native Hawaiian and Other Pacific Islander alone", "Two or More Races", "Hispanic or Latino"]

county = ['San Francisco County, California',
                'New York County (Manhattan Borough), New York', 
                 'King County, Washington',
                'Multnomah County, Oregon', 
                 'Kings County (Brooklyn Borough), New York',
                'Cook County, Illinois']

N = 6
ind = np.arange(N)
width = .75

#White
white = out_race.iloc[0, 1:7]

#African America
aa = out_race.iloc[1, 1:7]

#American Indian & Alaska Native
ai = out_race.iloc[2, 1:7]

#Native Hawaiian and Other Pacific
hawaiian = out_race.iloc[3, 1:7]

#Asian
asian = out_race.iloc[4, 1:7]

#Two or More Races
two = out_race.iloc[5, 1:7]

#Hispanic or Latino
hispanic = out_race.iloc[6, 1:7]

p1 = plt.bar(ind,white,width)
p2 = plt.bar(ind,aa,width, bottom=white)
p3 = plt.bar(ind,ai,width, bottom=white+aa)
p4 = plt.bar(ind,hawaiian,width, bottom=white+aa+ai)
p5 = plt.bar(ind,asian,width, bottom=white+aa+ai+hawaiian)
p6 = plt.bar(ind,two,width, bottom =white+aa+ai+hawaiian+asian)
p7 = plt.bar(ind,hispanic,width, bottom =white+aa+ai+hawaiian+asian+two)




plt.ylabel('By Percentage')
plt.title('Race')
plt.xticks(ind, ('San Francisco', 'Manhattan', 'King County (WA)', 'Multnomah County (OR)',
                'Brooklyn', 'Chicago'),rotation='vertical')

                
plt.legend((p1[0], p2[0], p3[0], 
            p4[0], p5[0],p6[0], p7[0]),
           ('White', 'African American', 
            'American Indian or Alaska Native',
            'Hawaiian or Other Pacific', 'Asian', 
            'Two or More Races', 'Hispanic'),loc='upper right',
          bbox_to_anchor =(1.65, 1.0))

plt.show()

# %%
#Age

out_age =out_df.iloc[7:10,0:7]
out_age.head()
# Out:
#                                  Fact Cook County, Illinois  \
# 7      Persons under 5 years, percent                  6.2%
# 8     Persons under 18 years, percent                 22.0%
# 9  Persons 65 years and over, percent                 14.3%
#
#   Kings County (Brooklyn Borough), New York Multnomah County, Oregon  \
# 7                                      7.3%                     5.6%
# 8                                     22.9%                    19.1%
# 9                                     13.5%                    13.0%
#
#   King County, Washington New York County (Manhattan Borough), New York  \
# 7                    5.9%                                          4.8%
# 8                   20.4%                                         14.4%
# 9                   13.0%                                         16.0%
#
#   San Francisco County, California
# 7                             4.5%
# 8                            13.4%
# 9                            15.4%

# %%
out_age['Cook County, Illinois'] = out_age['Cook County, Illinois'].apply(lambda x: float(x[:-1]))
out_age['Kings County (Brooklyn Borough), New York'] = out_age['Kings County (Brooklyn Borough), New York'].apply(lambda x: float(x[:-1]))
out_age['Multnomah County, Oregon'] = out_age['Multnomah County, Oregon'].apply(lambda x: float(x[:-1]))
out_age['King County, Washington'] = out_age['King County, Washington'].apply(lambda x: float(x[:-1]))
out_age['New York County (Manhattan Borough), New York'] = out_age['New York County (Manhattan Borough), New York'].apply(lambda x: float(x[:-1]))
out_age['San Francisco County, California'] = out_age['San Francisco County, California'].apply(lambda x: float(x[:-1]))


out_age['Fact'] = out_age['Fact'].apply(lambda x: x[:-9])
out_age
# Out:
#                         Fact  Cook County, Illinois  \
# 7      Persons under 5 years                    6.2
# 8     Persons under 18 years                   22.0
# 9  Persons 65 years and over                   14.3
#
#    Kings County (Brooklyn Borough), New York  Multnomah County, Oregon  \
# 7                                        7.3                       5.6
# 8                                       22.9                      19.1
# 9                                       13.5                      13.0
#
#    King County, Washington  New York County (Manhattan Borough), New York  \
# 7                      5.9                                            4.8
# 8                     20.4                                           14.4
# 9                     13.0                                           16.0
#
#    San Francisco County, California
# 7                               4.5
# 8                              13.4
# 9                              15.4

# %%
#add 18-65
#add "bottom"


county = ['San Francisco County, California',
                'New York County (Manhattan Borough), New York', 
                 'King County, Washington',
                'Multnomah County, Oregon', 
                 'Kings County (Brooklyn Borough), New York',
                'Cook County, Illinois']

age = ['under 5 years','under 18 years','65 years and over, percent']

N = 6
ind = np.arange(N)
width = 0.50

#Under 5
under_5 = out_age.iloc[0, 1:7]

#Under 18
under_18 = out_age.iloc[1, 1:7]

#Over 65
over_65 = out_age.iloc[2, 1:7]

#Plot
p1 = plt.bar(ind,under_5,width)
p2 = plt.bar(ind,under_18,width,bottom=under_5)
p3 = plt.bar(ind,over_65,width,bottom=under_5+under_18)

plt.legend((p1[0], p2[0], p3[0]),
           ('Under 5', 'Under 18', 
            'Over 65'),loc='upper right',
          bbox_to_anchor =(1.65, 1.0))



plt.ylabel('By Percentage')
plt.title('Age')
plt.xticks(ind, ('San Francisco', 'Manhattan', 'King County (WA)', 'Multnomah County (OR)',
                'Brooklyn', 'Chicago'),rotation='vertical')

plt.show()

# %%
#Sex
out_sex = out_df.iloc[10:11,0:7]
out_sex = pd.DataFrame(out_sex)
out_sex
# Out:
#                        Fact Cook County, Illinois  \
# 10  Female persons, percent                 51.4%
#
#    Kings County (Brooklyn Borough), New York Multnomah County, Oregon  \
# 10                                     52.6%                    50.5%
#
#    King County, Washington New York County (Manhattan Borough), New York  \
# 10                   49.9%                                         52.6%
#
#    San Francisco County, California
# 10                            49.0%

# %%
out_sex['Cook County, Illinois'] = out_sex['Cook County, Illinois'].apply(lambda x: float(x[:-1]))
out_sex['Kings County (Brooklyn Borough), New York'] = out_sex['Kings County (Brooklyn Borough), New York'].apply(lambda x: float(x[:-1]))
out_sex['Multnomah County, Oregon'] = out_sex['Multnomah County, Oregon'].apply(lambda x: float(x[:-1]))
out_sex['King County, Washington'] = out_sex['King County, Washington'].apply(lambda x: float(x[:-1]))
out_sex['New York County (Manhattan Borough), New York'] = out_sex['New York County (Manhattan Borough), New York'].apply(lambda x: float(x[:-1]))
out_sex['San Francisco County, California'] = out_sex['San Francisco County, California'].apply(lambda x: float(x[:-1]))


out_sex['Fact'] = out_sex['Fact'].apply(lambda x: x[:-9])
out_sex
# Out:
#               Fact  Cook County, Illinois  \
# 10  Female persons                   51.4
#
#     Kings County (Brooklyn Borough), New York  Multnomah County, Oregon  \
# 10                                       52.6                      50.5
#
#     King County, Washington  New York County (Manhattan Borough), New York  \
# 10                     49.9                                           52.6
#
#     San Francisco County, California
# 10                              49.0

# %%
female = out_sex.iloc[0]
female
# female = female.drop('Los Angeles County, California')
# Out:
# Fact                                             Female persons
# Cook County, Illinois                                      51.4
# Kings County (Brooklyn Borough), New York                  52.6
# Multnomah County, Oregon                                   50.5
# King County, Washington                                    49.9
# New York County (Manhattan Borough), New York              52.6
# San Francisco County, California                             49
# Name: 10, dtype: object

# %%
county = ['San Francisco County, California',
                'New York County (Manhattan Borough), New York', 
                 'King County, Washington',
                'Multnomah County, Oregon', 
                 'Kings County (Brooklyn Borough), New York',
                'Cook County, Illinois']

N = 6
ind = np.arange(N)
width = 0.50

#Female
female = out_sex.iloc[0, 1:7]

#Male
male_sex = 100-female


#Plot
p1 = plt.bar(ind,female,width)
p2 = plt.bar(ind,male_sex,width,bottom=female)

plt.legend((p1[0], p2[0]),
           ('Female', 'Male'),loc='upper right',
          bbox_to_anchor =(1.65, 1.0))

plt.ylabel('By Percentage')
plt.title('Sex')
plt.xticks(ind, ('San Francisco', 'Manhattan', 'King County (WA)', 'Multnomah County (OR)',
                'Brooklyn', 'Chicago'),rotation='vertical')

plt.show()

# %%
marital_out_df = pd.read_csv('Out of State - Marital.csv')

# marital_ca_df.reindex(columns = column_titles)

marital_out_df=marital_out_df.transpose()

marital_out_df.head(115-150)

marital_out_df.to_csv('outstate_marital_transpose.csv')
marital_out_df

# cols = list(marital_ca_df.columns.values)
# cols

# column_titles = ['Fact',
#                 'San Francisco County, California',
#                 'Alameda County, California', 
#                  'San Mateo County, California',
#                 'Contra Costa County, California', 
#                  'Los Angeles County, California',
#                 'Santa Clara County, California']
marital_out_df = marital_out_df.reindex(columns = [0, 3, 5, 4, 2, 1])
# marital_ca_df.reindex(columns = column_titles)
marital_out_df
# Out:
#                                                                                    0  \
# Id                                                                    0500000US06075
# Id2                                                                             6075
# Geography                                           San Francisco County, California
# Total; Estimate; Population 15 years and over                                 764957
# Total; Margin of Error; Population 15 years and...                               108
# Now married (except separated); Estimate; Popul...                              39.8
# Now married (except separated); Margin of Error...                               0.5
# Widowed; Estimate; Population 15 years and over                                  4.7
# Widowed; Margin of Error; Population 15 years a...                               0.2
# Divorced; Estimate; Population 15 years and over                                 8.3
# Divorced; Margin of Error; Population 15 years ...                               0.2
# Separated; Estimate; Population 15 years and over                                1.4
# Separated; Margin of Error; Population 15 years...                               0.1
# Never married; Estimate; Population 15 years an...                              45.8
# Never married; Margin of Error; Population 15 y...                               0.4
# Total; Estimate; AGE AND SEX - Males 15 years a...                            389829
# Total; Margin of Error; AGE AND SEX - Males 15 ...                               108
# Now married (except separated); Estimate; AGE A...                              40.1
# Now married (except separated); Margin of Error...                               0.5
# Widowed; Estimate; AGE AND SEX - Males 15 years...                               1.7
# Widowed; Margin of Error; AGE AND SEX - Males 1...                               0.1
# Divorced; Estimate; AGE AND SEX - Males 15 year...                               6.9
# Divorced; Margin of Error; AGE AND SEX - Males ...                               0.3
# Separated; Estimate; AGE AND SEX - Males 15 yea...                               1.3
# Separated; Margin of Error; AGE AND SEX - Males...                               0.1
# Never married; Estimate; AGE AND SEX - Males 15...                                50
# Never married; Margin of Error; AGE AND SEX - M...                               0.5
# Total; Estimate; AGE AND SEX - Males 15 years a...                             14920
# Total; Margin of Error; AGE AND SEX - Males 15 ...                               122
# Now married (except separated); Estimate; AGE A...                                 1
# ...                                                                              ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                               6.1
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                               0.4
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                               1.1
# Separated; Margin of Error; LABOR FORCE PARTICI...                               0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                                52
# Never married; Margin of Error; LABOR FORCE PAR...                               0.6
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                            372556
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                               286
# Now married (except separated); Estimate; LABOR...                              39.7
# Now married (except separated); Margin of Error...                               0.6
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                               7.9
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                               0.3
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                               9.8
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                               0.3
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                               1.5
# Separated; Margin of Error; LABOR FORCE PARTICI...                               0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                              41.1
# Never married; Margin of Error; LABOR FORCE PAR...                               0.5
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                            246686
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                              1569
# Now married (except separated); Estimate; LABOR...                              39.8
# Now married (except separated); Margin of Error...                               0.8
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                               1.8
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                               0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                               9.3
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                               0.4
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                               1.6
# Separated; Margin of Error; LABOR FORCE PARTICI...                               0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                              47.5
# Never married; Margin of Error; LABOR FORCE PAR...                               0.7
#
#                                                                             3  \
# Id                                                             0500000US36061
# Id2                                                                     36061
# Geography                                           New York County, New York
# Total; Estimate; Population 15 years and over                         1448890
# Total; Margin of Error; Population 15 years and...                         48
# Now married (except separated); Estimate; Popul...                       34.1
# Now married (except separated); Margin of Error...                        0.4
# Widowed; Estimate; Population 15 years and over                           4.8
# Widowed; Margin of Error; Population 15 years a...                        0.1
# Divorced; Estimate; Population 15 years and over                          8.4
# Divorced; Margin of Error; Population 15 years ...                        0.2
# Separated; Estimate; Population 15 years and over                         2.6
# Separated; Margin of Error; Population 15 years...                        0.1
# Never married; Estimate; Population 15 years an...                         50
# Never married; Margin of Error; Population 15 y...                        0.4
# Total; Estimate; AGE AND SEX - Males 15 years a...                     678406
# Total; Margin of Error; AGE AND SEX - Males 15 ...                         72
# Now married (except separated); Estimate; AGE A...                       37.3
# Now married (except separated); Margin of Error...                        0.5
# Widowed; Estimate; AGE AND SEX - Males 15 years...                        2.1
# Widowed; Margin of Error; AGE AND SEX - Males 1...                        0.2
# Divorced; Estimate; AGE AND SEX - Males 15 year...                        6.7
# Divorced; Margin of Error; AGE AND SEX - Males ...                        0.3
# Separated; Estimate; AGE AND SEX - Males 15 yea...                        2.1
# Separated; Margin of Error; AGE AND SEX - Males...                        0.2
# Never married; Estimate; AGE AND SEX - Males 15...                       51.7
# Never married; Margin of Error; AGE AND SEX - M...                        0.5
# Total; Estimate; AGE AND SEX - Males 15 years a...                      32874
# Total; Margin of Error; AGE AND SEX - Males 15 ...                         71
# Now married (except separated); Estimate; AGE A...                        1.1
# ...                                                                       ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                        6.3
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                        0.4
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                        1.8
# Separated; Margin of Error; LABOR FORCE PARTICI...                        0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                       50.4
# Never married; Margin of Error; LABOR FORCE PAR...                        0.7
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                     764836
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                        467
# Now married (except separated); Estimate; LABOR...                       31.6
# Now married (except separated); Margin of Error...                        0.4
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                        7.2
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                        0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                         10
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                        0.3
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                        3.1
# Separated; Margin of Error; LABOR FORCE PARTICI...                        0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                       48.1
# Never married; Margin of Error; LABOR FORCE PAR...                        0.5
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                     477284
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                       2929
# Now married (except separated); Estimate; LABOR...                       32.6
# Now married (except separated); Margin of Error...                        0.6
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                        1.9
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                        0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                        9.3
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                        0.4
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                        2.8
# Separated; Margin of Error; LABOR FORCE PARTICI...                        0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                       53.4
# Never married; Margin of Error; LABOR FORCE PAR...                        0.7
#
#                                                                           5  \
# Id                                                           0500000US53033
# Id2                                                                   53033
# Geography                                           King County, Washington
# Total; Estimate; Population 15 years and over                       1748964
# Total; Margin of Error; Population 15 years and...                    *****
# Now married (except separated); Estimate; Popul...                     50.1
# Now married (except separated); Margin of Error...                      0.4
# Widowed; Estimate; Population 15 years and over                         4.2
# Widowed; Margin of Error; Population 15 years a...                      0.1
# Divorced; Estimate; Population 15 years and over                       10.1
# Divorced; Margin of Error; Population 15 years ...                      0.2
# Separated; Estimate; Population 15 years and over                       1.3
# Separated; Margin of Error; Population 15 years...                      0.1
# Never married; Estimate; Population 15 years an...                     34.2
# Never married; Margin of Error; Population 15 y...                      0.3
# Total; Estimate; AGE AND SEX - Males 15 years a...                   870412
# Total; Margin of Error; AGE AND SEX - Males 15 ...                    *****
# Now married (except separated); Estimate; AGE A...                       51
# Now married (except separated); Margin of Error...                      0.5
# Widowed; Estimate; AGE AND SEX - Males 15 years...                      1.7
# Widowed; Margin of Error; AGE AND SEX - Males 1...                      0.1
# Divorced; Estimate; AGE AND SEX - Males 15 year...                      8.4
# Divorced; Margin of Error; AGE AND SEX - Males ...                      0.2
# Separated; Estimate; AGE AND SEX - Males 15 yea...                      1.1
# Separated; Margin of Error; AGE AND SEX - Males...                      0.1
# Never married; Estimate; AGE AND SEX - Males 15...                     37.8
# Never married; Margin of Error; AGE AND SEX - M...                      0.4
# Total; Estimate; AGE AND SEX - Males 15 years a...                    59395
# Total; Margin of Error; AGE AND SEX - Males 15 ...                    *****
# Now married (except separated); Estimate; AGE A...                      0.8
# ...                                                                     ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                        8
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                      0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                      1.2
# Separated; Margin of Error; LABOR FORCE PARTICI...                      0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                     36.1
# Never married; Margin of Error; LABOR FORCE PAR...                      0.4
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                   867422
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                      604
# Now married (except separated); Estimate; LABOR...                     49.9
# Now married (except separated); Margin of Error...                      0.4
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                      6.7
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                      0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                     12.1
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                      0.3
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                      1.5
# Separated; Margin of Error; LABOR FORCE PARTICI...                      0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                     29.8
# Never married; Margin of Error; LABOR FORCE PAR...                      0.3
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                   550447
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                     2678
# Now married (except separated); Estimate; LABOR...                     49.1
# Now married (except separated); Margin of Error...                      0.5
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                      1.8
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                      0.1
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                     12.6
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                      0.3
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                      1.8
# Separated; Margin of Error; LABOR FORCE PARTICI...                      0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                     34.7
# Never married; Margin of Error; LABOR FORCE PAR...                      0.4
#
#                                                                            4  \
# Id                                                            0500000US41051
# Id2                                                                    41051
# Geography                                           Multnomah County, Oregon
# Total; Estimate; Population 15 years and over                         657931
# Total; Margin of Error; Population 15 years and...                     *****
# Now married (except separated); Estimate; Popul...                      42.5
# Now married (except separated); Margin of Error...                       0.6
# Widowed; Estimate; Population 15 years and over                          4.3
# Widowed; Margin of Error; Population 15 years a...                       0.2
# Divorced; Estimate; Population 15 years and over                        12.6
# Divorced; Margin of Error; Population 15 years ...                       0.3
# Separated; Estimate; Population 15 years and over                        1.8
# Separated; Margin of Error; Population 15 years...                       0.1
# Never married; Estimate; Population 15 years an...                      38.8
# Never married; Margin of Error; Population 15 y...                       0.4
# Total; Estimate; AGE AND SEX - Males 15 years a...                    323595
# Total; Margin of Error; AGE AND SEX - Males 15 ...                        49
# Now married (except separated); Estimate; AGE A...                      43.2
# Now married (except separated); Margin of Error...                       0.6
# Widowed; Estimate; AGE AND SEX - Males 15 years...                         2
# Widowed; Margin of Error; AGE AND SEX - Males 1...                       0.2
# Divorced; Estimate; AGE AND SEX - Males 15 year...                      10.8
# Divorced; Margin of Error; AGE AND SEX - Males ...                       0.4
# Separated; Estimate; AGE AND SEX - Males 15 yea...                       1.6
# Separated; Margin of Error; AGE AND SEX - Males...                       0.2
# Never married; Estimate; AGE AND SEX - Males 15...                      42.4
# Never married; Margin of Error; AGE AND SEX - M...                       0.5
# Total; Estimate; AGE AND SEX - Males 15 years a...                     20257
# Total; Margin of Error; AGE AND SEX - Males 15 ...                        60
# Now married (except separated); Estimate; AGE A...                       0.6
# ...                                                                      ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                       9.9
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                       0.4
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                       1.5
# Separated; Margin of Error; LABOR FORCE PARTICI...                       0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                      41.9
# Never married; Margin of Error; LABOR FORCE PAR...                       0.7
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                    329749
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                       394
# Now married (except separated); Estimate; LABOR...                      42.4
# Now married (except separated); Margin of Error...                       0.7
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                       6.6
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                       0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                      14.4
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                       0.5
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                       2.1
# Separated; Margin of Error; LABOR FORCE PARTICI...                       0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                      34.4
# Never married; Margin of Error; LABOR FORCE PAR...                       0.5
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                    214360
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                      1581
# Now married (except separated); Estimate; LABOR...                      42.7
# Now married (except separated); Margin of Error...                       0.8
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                       1.9
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                       0.2
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                      13.8
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                       0.5
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                       2.3
# Separated; Margin of Error; LABOR FORCE PARTICI...                       0.3
# Never married; Estimate; LABOR FORCE PARTICIPAT...                      39.3
# Never married; Margin of Error; LABOR FORCE PAR...                       0.7
#
#                                                                          2  \
# Id                                                          0500000US36047
# Id2                                                                  36047
# Geography                                           Kings County, New York
# Total; Estimate; Population 15 years and over                      2118407
# Total; Margin of Error; Population 15 years and...                      82
# Now married (except separated); Estimate; Popul...                    40.2
# Now married (except separated); Margin of Error...                     0.3
# Widowed; Estimate; Population 15 years and over                        5.4
# Widowed; Margin of Error; Population 15 years a...                     0.1
# Divorced; Estimate; Population 15 years and over                       7.1
# Divorced; Margin of Error; Population 15 years ...                     0.1
# Separated; Estimate; Population 15 years and over                      3.1
# Separated; Margin of Error; Population 15 years...                     0.1
# Never married; Estimate; Population 15 years an...                    44.1
# Never married; Margin of Error; Population 15 y...                     0.2
# Total; Estimate; AGE AND SEX - Males 15 years a...                  983628
# Total; Margin of Error; AGE AND SEX - Males 15 ...                      81
# Now married (except separated); Estimate; AGE A...                    43.9
# Now married (except separated); Margin of Error...                     0.3
# Widowed; Estimate; AGE AND SEX - Males 15 years...                     2.3
# Widowed; Margin of Error; AGE AND SEX - Males 1...                     0.1
# Divorced; Estimate; AGE AND SEX - Males 15 year...                     5.4
# Divorced; Margin of Error; AGE AND SEX - Males ...                     0.1
# Separated; Estimate; AGE AND SEX - Males 15 yea...                     2.3
# Separated; Margin of Error; AGE AND SEX - Males...                     0.1
# Never married; Estimate; AGE AND SEX - Males 15...                    46.1
# Never married; Margin of Error; AGE AND SEX - M...                     0.3
# Total; Estimate; AGE AND SEX - Males 15 years a...                   74251
# Total; Margin of Error; AGE AND SEX - Males 15 ...                     119
# Now married (except separated); Estimate; AGE A...                       1
# ...                                                                    ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                       5
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                     0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                     2.2
# Separated; Margin of Error; LABOR FORCE PARTICI...                     0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                      44
# Never married; Margin of Error; LABOR FORCE PAR...                     0.4
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                 1119927
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                     686
# Now married (except separated); Estimate; LABOR...                    37.5
# Now married (except separated); Margin of Error...                     0.3
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                     8.3
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                     0.1
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                     8.7
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                     0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                     3.9
# Separated; Margin of Error; LABOR FORCE PARTICI...                     0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                    41.6
# Never married; Margin of Error; LABOR FORCE PAR...                     0.3
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                  660879
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                    2981
# Now married (except separated); Estimate; LABOR...                    38.3
# Now married (except separated); Margin of Error...                     0.4
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                     2.4
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                     0.1
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                       9
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                     0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                     4.2
# Separated; Margin of Error; LABOR FORCE PARTICI...                     0.2
# Never married; Estimate; LABOR FORCE PARTICIPAT...                    46.1
# Never married; Margin of Error; LABOR FORCE PAR...                     0.4
#
#                                                                         1
# Id                                                         0500000US17031
# Id2                                                                 17031
# Geography                                           Cook County, Illinois
# Total; Estimate; Population 15 years and over                     4260374
# Total; Margin of Error; Population 15 years and...                     42
# Now married (except separated); Estimate; Popul...                     42
# Now married (except separated); Margin of Error...                    0.2
# Widowed; Estimate; Population 15 years and over                       5.8
# Widowed; Margin of Error; Population 15 years a...                    0.1
# Divorced; Estimate; Population 15 years and over                      8.7
# Divorced; Margin of Error; Population 15 years ...                    0.1
# Separated; Estimate; Population 15 years and over                     2.1
# Separated; Margin of Error; Population 15 years...                    0.1
# Never married; Estimate; Population 15 years an...                   41.5
# Never married; Margin of Error; Population 15 y...                    0.2
# Total; Estimate; AGE AND SEX - Males 15 years a...                2043238
# Total; Margin of Error; AGE AND SEX - Males 15 ...                     37
# Now married (except separated); Estimate; AGE A...                   44.4
# Now married (except separated); Margin of Error...                    0.3
# Widowed; Estimate; AGE AND SEX - Males 15 years...                    2.5
# Widowed; Margin of Error; AGE AND SEX - Males 1...                    0.1
# Divorced; Estimate; AGE AND SEX - Males 15 year...                    7.2
# Divorced; Margin of Error; AGE AND SEX - Males ...                    0.1
# Separated; Estimate; AGE AND SEX - Males 15 yea...                    1.8
# Separated; Margin of Error; AGE AND SEX - Males...                    0.1
# Never married; Estimate; AGE AND SEX - Males 15...                   44.1
# Never married; Margin of Error; AGE AND SEX - M...                    0.2
# Total; Estimate; AGE AND SEX - Males 15 years a...                 163521
# Total; Margin of Error; AGE AND SEX - Males 15 ...                     61
# Now married (except separated); Estimate; AGE A...                    0.8
# ...                                                                   ...
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                    6.9
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                    0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                    1.7
# Separated; Margin of Error; LABOR FORCE PARTICI...                    0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                   42.4
# Never married; Margin of Error; LABOR FORCE PAR...                    0.3
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                2185548
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                   1014
# Now married (except separated); Estimate; LABOR...                   40.3
# Now married (except separated); Margin of Error...                    0.3
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                      9
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                    0.1
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                   10.2
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                    0.1
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                    2.4
# Separated; Margin of Error; LABOR FORCE PARTICI...                    0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                   38.2
# Never married; Margin of Error; LABOR FORCE PAR...                    0.2
# Total; Estimate; LABOR FORCE PARTICIPATION - Fe...                1325180
# Total; Margin of Error; LABOR FORCE PARTICIPATI...                   4444
# Now married (except separated); Estimate; LABOR...                   40.8
# Now married (except separated); Margin of Error...                    0.4
# Widowed; Estimate; LABOR FORCE PARTICIPATION - ...                    2.8
# Widowed; Margin of Error; LABOR FORCE PARTICIPA...                    0.1
# Divorced; Estimate; LABOR FORCE PARTICIPATION -...                   10.5
# Divorced; Margin of Error; LABOR FORCE PARTICIP...                    0.2
# Separated; Estimate; LABOR FORCE PARTICIPATION ...                    2.6
# Separated; Margin of Error; LABOR FORCE PARTICI...                    0.1
# Never married; Estimate; LABOR FORCE PARTICIPAT...                   43.3
# Never married; Margin of Error; LABOR FORCE PAR...                    0.3
#
# [231 rows x 6 columns]

# %%
male_single= marital_out_df.iloc[25]
male_married=marital_out_df.iloc[17]
male_widowed=marital_out_df.iloc[19]
male_divorced=marital_out_df.iloc[21]
male_separated=marital_out_df.iloc[23]


female_single= marital_out_df.iloc[109]
female_married=marital_out_df.iloc[101]
female_widowed=marital_out_df.iloc[103]
female_divorced=marital_out_df.iloc[105]
female_separated=marital_out_df.iloc[107]
# Out:
# 0    1.5
# 3    3.1
# 5    1.5
# 4    2.1
# 2    3.8
# 1    2.3
# Name: Separated; Estimate; AGE AND SEX - Females 15 years and over, dtype: object

# %%
N = 6
ind = np.arange(N)
width = 0.50

p1 = plt.bar(ind,male_single,width)
p2 = plt.bar(ind,male_married,width,bottom = male_single)
p3 = plt.bar(ind,male_widowed,width,bottom = male_single+male_married)
p4 = plt.bar(ind,male_divorced,width,bottom =male_single+male_married+male_widowed)
p5 = plt.bar(ind,male_separated,width,bottom= male_single+male_married+male_widowed+male_divorced)


plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]),
           ('Single', 'Married', "Widowed", "Divorced", "Separated"),loc='upper right',
          bbox_to_anchor =(1.65, 1.0))

plt.ylabel('By Percentage')
plt.title('Male Marital Status')
plt.xticks(ind, ('San Francisco', 'Alameda', 'San Mateo', 'Contra Costa',
                'Los Angeles', 'Santa Clara'),rotation='vertical')

plt.show()

# %%
N = 6
ind = np.arange(N)
width = 0.50

p1 = plt.bar(ind,female_single,width)
p2 = plt.bar(ind,female_married,width,bottom = female_single)
p3 = plt.bar(ind,female_widowed,width,bottom = female_single+female_married)
p4 = plt.bar(ind,female_divorced,width,bottom =female_single+female_married+female_widowed)
p5 = plt.bar(ind,female_separated,width,bottom= female_single+female_married+female_widowed+female_divorced)


plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]),
           ('Single', 'Married', "Widowed", "Divorced", "Separated"),loc='upper right',
          bbox_to_anchor =(1.65, 1.0))

plt.ylabel('By Percentage')
plt.title('Female Marital Status')
plt.xticks(ind, ('San Francisco', 'Alameda', 'San Mateo', 'Contra Costa',
                'Los Angeles', 'Santa Clara'),rotation='vertical')

plt.show()
