# %%
import pandas as pd
csv_path = "SF_ALL_OUT.csv"
sf_out_df = pd.read_csv(csv_path)

sf_out_df.head()
# Out:
#   State/County FIPS State FIPS County FIPS       County Name State Name  \
# 0           '01073'       '01'       '073'  Jefferson County    Alabama
# 1           '01081'       '01'       '081'        Lee County    Alabama
# 2           '01089'       '01'       '089'    Madison County    Alabama
# 3           '01097'       '01'       '097'     Mobile County    Alabama
# 4           '01117'       '01'       '117'     Shelby County    Alabama
#
#    Total  Margin of Error (+/-)
# 0     43                     40
# 1      0                     27
# 2      5                      7
# 3     75                     96
# 4      0                     27

# %%
ranked_sf_out_df = sf_out_df.sort_values(by='Total', ascending=False)
ranked_sf_out_df.head(20)
# Out:
#     State/County FIPS State FIPS County FIPS          County Name  \
# 19            '06001'       '06'       '001'       Alameda County
# 52            '06081'       '06'       '081'     San Mateo County
# 25            '06013'       '06'       '013'  Contra Costa County
# 34            '06037'       '06'       '037'   Los Angeles County
# 54            '06085'       '06'       '085'   Santa Clara County
# 36            '06041'       '06'       '041'         Marin County
# 60            '06097'       '06'       '097'        Sonoma County
# 259           '36061'       '36'       '061'      New York County
# 46            '06067'       '06'       '067'    Sacramento County
# 413           '53033'       '53'       '033'          King County
# 326           '41051'       '41'       '051'     Multnomah County
# 50            '06077'       '06'       '077'   San Joaquin County
# 255           '36047'       '36'       '047'         Kings County
# 59            '06095'       '06'       '095'        Solano County
# 43            '06059'       '06'       '059'        Orange County
# 49            '06073'       '06'       '073'     San Diego County
# 131           '17031'       '17'       '031'          Cook County
# 67            '06113'       '06'       '113'          Yolo County
# 186           '25025'       '25'       '025'       Suffolk County
# 45            '06065'       '06'       '065'     Riverside County
#
#         State Name  Total  Margin of Error (+/-)
# 19      California  10791                   1127
# 52      California   8995                   1054
# 25      California   4085                    631
# 34      California   3726                    547
# 54      California   3383                    447
# 36      California   2859                    525
# 60      California   1479                    306
# 259       New York   1419                    657
# 46      California   1355                    385
# 413     Washington   1293                    336
# 326         Oregon   1094                    282
# 50      California    932                    267
# 255       New York    887                    300
# 59      California    725                    265
# 43      California    715                    228
# 49      California    697                    226
# 131       Illinois    635                    223
# 67      California    573                    215
# 186  Massachusetts    546                    203
# 45      California    513                    287

# %%
sf_to_ca = ranked_sf_out_df.loc[ranked_sf_out_df["State Name"] == "California",:]
sf_to_ca.head(10)
# Out:
#    State/County FIPS State FIPS County FIPS          County Name  State Name  \
# 19           '06001'       '06'       '001'       Alameda County  California
# 52           '06081'       '06'       '081'     San Mateo County  California
# 25           '06013'       '06'       '013'  Contra Costa County  California
# 34           '06037'       '06'       '037'   Los Angeles County  California
# 54           '06085'       '06'       '085'   Santa Clara County  California
# 36           '06041'       '06'       '041'         Marin County  California
# 60           '06097'       '06'       '097'        Sonoma County  California
# 46           '06067'       '06'       '067'    Sacramento County  California
# 50           '06077'       '06'       '077'   San Joaquin County  California
# 59           '06095'       '06'       '095'        Solano County  California
#
#     Total  Margin of Error (+/-)
# 19  10791                   1127
# 52   8995                   1054
# 25   4085                    631
# 34   3726                    547
# 54   3383                    447
# 36   2859                    525
# 60   1479                    306
# 46   1355                    385
# 50    932                    267
# 59    725                    265

# %%
sf_not_ca = ranked_sf_out_df.loc[ranked_sf_out_df["State Name"] != "California",:]
sf_not_ca.head(10)
# Out:
#     State/County FIPS State FIPS County FIPS       County Name     State Name  \
# 259           '36061'       '36'       '061'   New York County       New York
# 413           '53033'       '53'       '033'       King County     Washington
# 326           '41051'       '41'       '051'  Multnomah County         Oregon
# 255           '36047'       '36'       '047'      Kings County       New York
# 131           '17031'       '17'       '031'       Cook County       Illinois
# 186           '25025'       '25'       '025'    Suffolk County  Massachusetts
# 74            '08031'       '08'       '031'     Denver County       Colorado
# 183           '25017'       '25'       '017'  Middlesex County  Massachusetts
# 10            '04013'       '04'       '013'   Maricopa County        Arizona
# 227           '32031'       '32'       '031'     Washoe County         Nevada
#
#      Total  Margin of Error (+/-)
# 259   1419                    657
# 413   1293                    336
# 326   1094                    282
# 255    887                    300
# 131    635                    223
# 186    546                    203
# 74     437                    180
# 183    394                    153
# 10     394                    187
# 227    359                    151
