# %% [markdown]
# # Wage data from census "QuickFacts" utility
#
# ### Reference:  https://www.census.gov/quickfacts/fact/table/US/PST045218

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Files to load
within_ca_data = "QuickFacts Feb-05-2019 In CA.csv"
moveout_ca_data = "QuickFacts Feb-05-2019 Outside CA.csv"

# read the county data for migration within CA and out of CA
in_ca_df = pd.read_csv(within_ca_data)
out_ca_df = pd.read_csv(moveout_ca_data)

#del in_ca_df["Fact Note"]
#del out_ca_df["Fact Note"]

# %%
#Look at the columns from the DataFrame
in_ca_df.head()
# Out:
#                                                 Fact Fact Note  \
# 0       Population estimates, July 1, 2017,  (V2017)       NaN
# 1  Population estimates base, April 1, 2010,  (V2...       NaN
# 2  Population, percent change - April 1, 2010 (es...       NaN
# 3                  Population, Census, April 1, 2010       NaN
# 4                     Persons under 5 years, percent       NaN
#
#   San Francisco County, California Alameda County, California  \
# 0                          884,363                  1,663,190
# 1                          805,193                  1,510,261
# 2                            9.80%                     10.10%
# 3                          805,235                  1,510,271
# 4                            4.50%                      5.90%
#
#   San Mateo County, California Contra Costa County, California  \
# 0                      771,410                       1,147,439
# 1                      718,500                       1,049,200
# 2                        7.40%                           9.40%
# 3                      718,451                       1,049,025
# 4                        5.70%                           5.70%
#
#   Los Angeles County, California Santa Clara County, California
# 0                     10,163,507                      1,938,153
# 1                      9,818,696                      1,781,671
# 2                          3.50%                          8.80%
# 3                      9,818,605                      1,781,642
# 4                          6.10%                          6.10%

# %%
# Rename the columns, look at the DataFrame
ca_df = in_ca_df.rename(columns={"San Francisco County, California": "San Francisco",
                                 "Alameda County, California":"Alameda",
                                 "San Mateo County, California":"San Mateo",
                                 "Contra Costa County, California":"Contra Costa",
                                "Los Angeles County, California":"Los Angeles",
                                "Santa Clara County, California":"Santa Clara"
                                            })

# Remove the "Fact Note" column
ca_df = ca_df[["Fact","San Francisco", "Alameda", "San Mateo", 
              "Contra Costa", "Los Angeles", "Santa Clara"]]

# Only keep the top 62 rows of data
ca_df = ca_df[:62]

# Move the Facts into the index to get it out of the way since we don't need to clean the numbers in that column
# Making a new DF ca_data,  so  you can always refer to ca_df to see the line number of the row
ca_data = ca_df.set_index("Fact")

# Clean the $ and % and " signs from multiple columns, first put the columns put them in a list
# Reference:  https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python

cols = ca_data.columns

# pass cols to df.replace(), specifying $,%" and , to be replaced by blanks

ca_data[cols] = ca_data[cols].replace({'\$': '', ',': '', '\%':'', '\"': ''}, regex=True)

ca_data.head()
# Out:
#                                                    San Francisco  Alameda  \
# Fact
# Population estimates, July 1, 2017,  (V2017)              884363  1663190
# Population estimates base, April 1, 2010,  (V2017)        805193  1510261
# Population, percent change - April 1, 2010 (est...          9.80    10.10
# Population, Census, April 1, 2010                         805235  1510271
# Persons under 5 years, percent                              4.50     5.90
#
#                                                    San Mateo Contra Costa  \
# Fact
# Population estimates, July 1, 2017,  (V2017)          771410      1147439
# Population estimates base, April 1, 2010,  (V2017)    718500      1049200
# Population, percent change - April 1, 2010 (est...      7.40         9.40
# Population, Census, April 1, 2010                     718451      1049025
# Persons under 5 years, percent                          5.70         5.70
#
#                                                    Los Angeles Santa Clara
# Fact
# Population estimates, July 1, 2017,  (V2017)          10163507     1938153
# Population estimates base, April 1, 2010,  (V2017)     9818696     1781671
# Population, percent change - April 1, 2010 (est...        3.50        8.80
# Population, Census, April 1, 2010                      9818605     1781642
# Persons under 5 years, percent                            6.10        6.10

# %%
# convert all objects to numerics
# reference:  https://stackoverflow.com/questions/36814100/pandas-to-numeric-for-multiple-columns
#cols = ca_data.columns[ca_data.dtypes.eq('object')]
clean_ca = ca_data[cols].apply(pd.to_numeric, errors='coerce')
clean_ca.head()
# Out:
#                                                     San Francisco    Alameda  \
# Fact
# Population estimates, July 1, 2017,  (V2017)             884363.0  1663190.0
# Population estimates base, April 1, 2010,  (V2017)       805193.0  1510261.0
# Population, percent change - April 1, 2010 (est...            9.8       10.1
# Population, Census, April 1, 2010                        805235.0  1510271.0
# Persons under 5 years, percent                                4.5        5.9
#
#                                                     San Mateo  Contra Costa  \
# Fact
# Population estimates, July 1, 2017,  (V2017)         771410.0     1147439.0
# Population estimates base, April 1, 2010,  (V2017)   718500.0     1049200.0
# Population, percent change - April 1, 2010 (est...        7.4           9.4
# Population, Census, April 1, 2010                    718451.0     1049025.0
# Persons under 5 years, percent                            5.7           5.7
#
#                                                     Los Angeles  Santa Clara
# Fact
# Population estimates, July 1, 2017,  (V2017)         10163507.0    1938153.0
# Population estimates base, April 1, 2010,  (V2017)    9818696.0    1781671.0
# Population, percent change - April 1, 2010 (est...          3.5          8.8
# Population, Census, April 1, 2010                     9818605.0    1781642.0
# Persons under 5 years, percent                              6.1          6.1

# %%
# Remove extraneous rows, keep only Median Wages
wages = clean_ca[44:45]

clean_ca.rename({"Median household income (in 2017 dollars), 2013-2017":"Median Income $"},axis=1)

wages
# Out:
#                                                     San Francisco  Alameda  \
# Fact
# Median household income (in 2017 dollars), 2013...        96265.0  85743.0
#
#                                                     San Mateo  Contra Costa  \
# Fact
# Median household income (in 2017 dollars), 2013...   105667.0       88456.0
#
#                                                     Los Angeles  Santa Clara
# Fact
# Median household income (in 2017 dollars), 2013...      61015.0     106761.0

# %%
# Now setup x and y axes for the bar plot

x_data = wages.columns.tolist()   #  x_data has the list of counties to be plotted
x_axis = np.arange(len(x_data))

print(x_data)            # Check that this is a list of counties
print(wages.values[0])   # this is accessing the first (and only) row of data


median_wage = wages.values[0]    #  [[1,2,3,4,5]] ->  row zero [0] [1,2,3,4,5]
# Out:
# ['San Francisco', 'Alameda', 'San Mateo', 'Contra Costa', 'Los Angeles', 'Santa Clara']
# [ 96265.  85743. 105667.  88456.  61015. 106761.]

# %%
plt.bar(x_axis, median_wage, color='blue', alpha=0.5, align="center")

tick_locations = [value for value in x_axis]
#print(tick_locations)

plt.xticks(tick_locations, x_data, rotation="35", ha='right')   #ha indicates the alignment of the xlabel with the tick mark
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(median_wage) + 10000)
plt.title("Median Wages for People Leaving San Francisco County")
plt.xlabel("Comparison between SF and Top 5 CA counties")
plt.ylabel("Median Salary, ($)")

# Add labels to give more context 

style = dict(size=8, color ='black')
plt.text(0.5,-45000, "Census 2012-2017, All data shown in 2017 dollars", **style)
#plt.text(1,-70000, "All data shown in 2017 dollars", **style)
# Out:
# Text(0.5,-45000,'Census 2012-2017, All data shown in 2017 dollars')

# %%
non_ca_df = out_ca_df.rename(columns={"San Francisco County, California":"San Francisco",
                                 "New York County (Manhattan Borough), New York":"NY County (Manhattan), NY",
                                 "King County, Washington":"King County, WA",
                                "Multnomah County, Oregon":"Multnomah County, OR",
                                "Kings County (Brooklyn Borough), New York":"Kings County (Brooklyn), NY",
                                "Cook County, Illinois":"Cook County, IL",
                                "Travis County, Texas":"Travis County, TX"
                                            })

non_ca_df = non_ca_df[["Fact","San Francisco County, CA", "NY County (Manhattan), NY", 
               "King County, WA", "Multnomah County, OR", "Kings County (Brooklyn), NY", 
                "Cook County, IL", "Travis County, TX"]]

# Remove extraneous rows, keep only Median Wages
non_ca_clean = non_ca_df[44:45]
non_ca_clean


# Exchange rows and columns,  first set "Fact" to index
non_ca_data = non_ca_clean.set_index("Fact")

non_ca_dataT = non_ca_data.transpose()
#others_wages =non_ca_dataT.values
non_ca_dataT

# %%
# Plot the comparison of Median Salaries for different counties


plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
