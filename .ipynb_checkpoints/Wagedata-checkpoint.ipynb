# %% [markdown]
# # Wage data from census "QuickFacts" utility
#
# ### Reference:  https://www.census.gov/quickfacts/fact/table/US/PST045218

# %% [markdown]
# # Wage Data For Top 5 Counties with Most Migration from SF County
#
# ## Data Workflow
#
# 1. Use the graphical interface to input up to 6 locations (by city, county, state, etc) https://www.census.gov/quickfacts/fact/table/US/PST045218
#
# ** In our case we have taken the then Top 5 counties with most migration from SF county -- both within California, and migration to other states
#
# ** The only data cleaning done was to add (for out-of-state),  Travis County TX, (Austin is located there),  which was added manually to the "non_CA_counties.csv" files
#
# 2. Import the csv
# *  Method: pd.read_csv
#
# 3. Clean up the data
# * Reduce the data size and clean up the naming (for easier reference later on)
#
# * df.drop()-    Drop columns all the columns which have no important data
# * df.dropna() - Drop rows with NaN
# * df.reset_index() - Reset the index because we had dropped out a few rows
# * df[:x] - Drop rows, only keep x rows
# * df.rename()  - Rename the colums with shorter names so the plots look ok
#
# 3.2      Transform the data.  Because of the %, $ the data inside the dataframe are all read in as objects
# *   Doing it this way will clean the entire table, and the user can specify different facts to be used
#
# *    df.set_index  - Move the "Fact" column into the index. That way the rest of the data will be cleaned of strings
# *    df.replace    - Replace the %, $, ,  in the data to blank
# *    df.apply(pd.to_numeric()) -- now change the objects in each column into numerics, "apply"  will apply to all cols
#
# 3.3      Setup to plot and plot
# *    df[x:y]        -Select the row or rows of data you need
# *    x_axis = np.arange(len(x_data)) -Set the x axis
# *                   -Set the values, extract if needed
# *    plt.bar()      - plot the bar chart

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Files to load
CA_counties = pd.read_csv("CA_counties.csv")
non_CA_counties = pd.read_csv("non_CA_counties.csv")

CA_counties.drop(columns = ['Fact Note'], inplace=True)
CA_counties.drop(columns = ['Value Note for San Francisco County, California'], inplace=True)
CA_counties.drop(columns = ['Value Note for Alameda County, California'], inplace=True)
CA_counties.drop(columns = ['Value Note for San Mateo County, California'], inplace=True)
CA_counties.drop(columns = ['Value Note for Contra Costa County, California'], inplace=True)
CA_counties.drop(columns = ['Value Note for Los Angeles County, California'], inplace=True)
CA_counties.drop(columns = ['Value Note for Santa Clara County, California'], inplace=True)

non_CA_counties.drop(columns = ['Fact Note'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for San Francisco County, California'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for King County, Washington'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for New York County (Manhattan Borough), New York'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for Multnomah County, Oregon'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for Kings County (Brooklyn Borough), New York'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for Cook County, Illinois'], inplace=True)
non_CA_counties.drop(columns = ['Value Note for Travis County, Texas'], inplace=True)

# Remove the rows which have NaNs,  doing inplace needed
CA_counties.dropna(inplace=True)
non_CA_counties.dropna(inplace=True)

# Reset the index to keep everything in order, drop = True means that the original index will be discarded
# Do this because we need to have one DF that shows the row number as a reference (later code)
# Reference:  https://stackoverflow.com/questions/33165734/update-index-after-sorting-data-frame

CA_counties.reset_index(drop=True, inplace=True)
non_CA_counties.reset_index(drop=True, inplace=True)


# Only keep the top 62 rows of data

CA_counties = CA_counties[:62]
non_CA_counties = non_CA_counties[:62]


CA_counties
# Out:
#                                                  Fact  \
# 0        Population estimates, July 1, 2017,  (V2017)
# 1   Population estimates base, April 1, 2010,  (V2...
# 2   Population, percent change - April 1, 2010 (es...
# 3                   Population, Census, April 1, 2010
# 4                      Persons under 5 years, percent
# 5                     Persons under 18 years, percent
# 6                  Persons 65 years and over, percent
# 7                             Female persons, percent
# 8                                White alone, percent
# 9            Black or African American alone, percent
# 10   American Indian and Alaska Native alone, percent
# 11                               Asian alone, percent
# 12  Native Hawaiian and Other Pacific Islander alo...
# 13                         Two or More Races, percent
# 14                        Hispanic or Latino, percent
# 15       White alone, not Hispanic or Latino, percent
# 16                                Veterans, 2013-2017
# 17           Foreign born persons, percent, 2013-2017
# 18             Housing units,  July 1, 2017,  (V2017)
# 19        Owner-occupied housing unit rate, 2013-2017
# 20  Median value of owner-occupied housing units, ...
# 21  Median selected monthly owner costs -with a mo...
# 22  Median selected monthly owner costs -without a...
# 23                       Median gross rent, 2013-2017
# 24                             Building permits, 2017
# 25                              Households, 2013-2017
# 26                   Persons per household, 2013-2017
# 27  Living in same house 1 year ago, percent of pe...
# 28  Language other than English spoken at home, pe...
# 29     Households with a computer, percent, 2013-2017
# ..                                                ...
# 32  Bachelor's degree or higher, percent of person...
# 33  With a disability, under age 65 years, percent...
# 34  Persons  without health insurance, under age 6...
# 35  In civilian labor force, total, percent of pop...
# 36  In civilian labor force, female, percent of po...
# 37  Total accommodation and food services sales, 2...
# 38  Total health care and social assistance receip...
# 39       Total manufacturers shipments, 2012 ($1,000)
# 40     Total merchant wholesaler sales, 2012 ($1,000)
# 41                  Total retail sales, 2012 ($1,000)
# 42                Total retail sales per capita, 2012
# 43  Mean travel time to work (minutes), workers ag...
# 44  Median household income (in 2017 dollars), 201...
# 45  Per capita income in past 12 months (in 2017 d...
# 46                        Persons in poverty, percent
# 47                Total employer establishments, 2016
# 48                             Total employment, 2016
# 49                Total annual payroll, 2016 ($1,000)
# 50        Total employment, percent change, 2015-2016
# 51             Total nonemployer establishments, 2016
# 52                                    All firms, 2012
# 53                              Men-owned firms, 2012
# 54                            Women-owned firms, 2012
# 55                         Minority-owned firms, 2012
# 56                      Nonminority-owned firms, 2012
# 57                          Veteran-owned firms, 2012
# 58                       Nonveteran-owned firms, 2012
# 59                   Population per square mile, 2010
# 60                    Land area in square miles, 2010
# 61                                          FIPS Code
#
#    San Francisco County, California Alameda County, California  \
# 0                           884,363                  1,663,190
# 1                           805,193                  1,510,261
# 2                             9.80%                     10.10%
# 3                           805,235                  1,510,271
# 4                             4.50%                      5.90%
# 5                            13.40%                     20.70%
# 6                            15.40%                     13.50%
# 7                            49.00%                     50.80%
# 8                            53.10%                     50.20%
# 9                             5.50%                     11.30%
# 10                            0.70%                      1.10%
# 11                           35.90%                     31.10%
# 12                            0.40%                      1.00%
# 13                            4.30%                      5.30%
# 14                           15.20%                     22.50%
# 15                           40.50%                     31.50%
# 16                           24,582                     53,532
# 17                           34.80%                     32.10%
# 18                          397,550                    606,052
# 19                           37.30%                     53.00%
# 20                        $927,400                   $649,100
# 21                          $3,332                     $2,675
# 22                            $615                       $608
# 23                          $1,709                     $1,547
# 24                            4,034                      9,258
# 25                          358,772                    569,070
# 26                             2.35                       2.81
# 27                           85.60%                     86.40%
# 28                           43.80%                     44.60%
# 29                           90.80%                     92.50%
# ..                              ...                        ...
# 32                           55.80%                     44.70%
# 33                            6.10%                      6.10%
# 34                            4.70%                      5.30%
# 35                           70.30%                     66.60%
# 36                           66.20%                     60.60%
# 37                        6,142,745                  3,192,420
# 38                       10,175,813                 12,949,087
# 39                                D                          D
# 40                       11,121,715                 37,580,614
# 41                       14,632,652                 20,901,014
# 42                         $17,718                    $13,444
# 43                             32.8                       32.5
# 44                         $96,265                    $85,743
# 45                         $59,508                    $41,363
# 46                           10.10%                      9.30%
# 47                           34,314                     39,242
# 48                          627,915                    662,511
# 49                       60,475,855                 45,907,712
# 50                            2.70%                      3.20%
# 51                           99,307                    143,612
# 52                          116,803                    150,564
# 53                           63,864                     76,387
# 54                           40,135                     57,305
# 55                           46,128                     75,026
# 56                           64,708                     69,300
# 57                            6,378                     10,213
# 58                          104,957                    134,032
# 59                        17,179.10                   2,043.60
# 60                            46.87                     739.02
# 61                          "06075"                    "06001"
#
#    San Mateo County, California Contra Costa County, California  \
# 0                       771,410                       1,147,439
# 1                       718,500                       1,049,200
# 2                         7.40%                           9.40%
# 3                       718,451                       1,049,025
# 4                         5.70%                           5.70%
# 5                        20.80%                          22.80%
# 6                        15.80%                          15.30%
# 7                        50.70%                          51.10%
# 8                        60.60%                          65.90%
# 9                         2.80%                           9.50%
# 10                        0.80%                           1.00%
# 11                       29.60%                          17.70%
# 12                        1.50%                           0.60%
# 13                        4.60%                           5.30%
# 14                       24.50%                          25.70%
# 15                       39.30%                          43.80%
# 16                       26,279                          49,218
# 17                       34.70%                          24.70%
# 18                      278,074                         414,007
# 19                       59.70%                          65.50%
# 20                    $917,700                        $522,300
# 21                      $3,227                          $2,527
# 22                        $689                            $634
# 23                      $1,973                          $1,600
# 24                        1,582                           1,984
# 25                      261,796                         389,597
# 26                         2.88                            2.86
# 27                       87.90%                          86.60%
# 28                       46.20%                          34.80%
# 29                       93.70%                          93.40%
# ..                          ...                             ...
# 32                       48.50%                          40.70%
# 33                        4.70%                           7.50%
# 34                        5.20%                           5.90%
# 35                       68.70%                          64.40%
# 36                       63.10%                          58.30%
# 37                    2,552,854                       1,659,988
# 38                    5,166,992                       8,262,635
# 39                            D                      33,681,206
# 40                   15,969,681                       6,887,164
# 41                   11,330,620                      11,847,866
# 42                     $15,326                         $10,974
# 43                         28.2                            37.1
# 44                    $105,667                         $88,456
# 45                     $53,516                         $42,898
# 46                        6.40%                           9.10%
# 47                       21,199                          23,591
# 48                      374,251                         325,864
# 49                   41,060,198                      21,468,960
# 50                       -0.70%                           3.30%
# 51                       71,514                          94,711
# 52                       75,507                          93,083
# 53                       39,910                          47,721
# 54                       26,594                          34,296
# 55                       30,914                          35,831
# 56                       40,894                          53,403
# 57                        5,141                           7,291
# 58                       66,645                          81,940
# 59                     1,602.20                        1,465.20
# 60                       448.41                          715.94
# 61                      "06081"                         "06013"
#
#    Los Angeles County, California Santa Clara County, California
# 0                      10,163,507                      1,938,153
# 1                       9,818,696                      1,781,671
# 2                           3.50%                          8.80%
# 3                       9,818,605                      1,781,642
# 4                           6.10%                          6.10%
# 5                          21.90%                         22.20%
# 6                          13.20%                         13.10%
# 7                          50.70%                         49.50%
# 8                          70.90%                         53.80%
# 9                           9.00%                          2.80%
# 10                          1.40%                          1.20%
# 11                         15.30%                         37.50%
# 12                          0.40%                          0.50%
# 13                          3.00%                          4.10%
# 14                         48.60%                         25.60%
# 15                         26.20%                         31.60%
# 16                        280,109                         55,763
# 17                         34.40%                         38.60%
# 18                      3,542,636                        671,125
# 19                         45.90%                         56.90%
# 20                      $495,800                       $829,600
# 21                        $2,336                         $3,081
# 22                          $556                           $709
# 23                        $1,322                         $1,955
# 24                         21,574                          7,968
# 25                      3,295,198                        630,451
# 26                           3.01                           2.98
# 27                         88.60%                         85.40%
# 28                         56.60%                         52.40%
# 29                         88.70%                         94.40%
# ..                            ...                            ...
# 32                         31.20%                         50.00%
# 33                          6.20%                          4.40%
# 34                         10.70%                          5.10%
# 35                         64.30%                         67.30%
# 36                         57.80%                         59.90%
# 37                     22,965,135                      4,809,201
# 38                     67,261,267                     17,020,991
# 39                    163,829,606                     41,450,609
# 40                    199,804,798                     91,858,973
# 41                    121,389,378                     40,336,741
# 42                       $12,184                        $21,952
# 43                           30.9                             28
# 44                       $61,015                       $106,761
# 45                       $30,798                        $48,689
# 46                         14.90%                          7.50%
# 47                        269,489                         48,278
# 48                      3,871,716                      1,021,748
# 49                    212,488,786                    114,930,448
# 50                         -3.40%                          2.20%
# 51                      1,046,426                        143,480
# 52                      1,146,701                        163,130
# 53                        601,676                         84,501
# 54                        439,513                         58,589
# 55                        631,218                         82,931
# 56                        481,643                         72,818
# 57                         69,608                          9,400
# 58                      1,044,750                        146,384
# 59                       2,419.60                       1,381.00
# 60                       4,057.88                       1,290.10
# 61                        "06037"                        "06085"
#
# [62 rows x 7 columns]

# %%
# Rename the columns, look at the DataFrame
CA_counties = CA_counties.rename(columns={"San Francisco County, California": "San Francisco",
                                 "Alameda County, California":"Alameda",
                                 "San Mateo County, California":"San Mateo",
                                 "Contra Costa County, California":"Contra Costa",
                                "Los Angeles County, California":"Los Angeles",
                                "Santa Clara County, California":"Santa Clara"
                                            })


# Move the Facts into the index to get it out of the way since we don't need to clean the numbers in that column
# Making a new DF ca_data,  so  you can always refer to ca_df to see the line number of the row
ca_data = CA_counties.set_index("Fact")

# Clean the $ and % and " signs from multiple columns, first put the columns put them in a list
# Reference:  https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python

cols = ca_data.columns

# pass cols to df.replace(), specifying $,%" and , to be replaced by blanks

ca_data[cols] = ca_data[cols].replace({'\$': '', ',': '', '\%':'', '\"': ''}, regex=True)

ca_data
# Out:
#                                                    San Francisco   Alameda  \
# Fact
# Population estimates, July 1, 2017,  (V2017)              884363   1663190
# Population estimates base, April 1, 2010,  (V2017)        805193   1510261
# Population, percent change - April 1, 2010 (est...          9.80     10.10
# Population, Census, April 1, 2010                         805235   1510271
# Persons under 5 years, percent                              4.50      5.90
# Persons under 18 years, percent                            13.40     20.70
# Persons 65 years and over, percent                         15.40     13.50
# Female persons, percent                                    49.00     50.80
# White alone, percent                                       53.10     50.20
# Black or African American alone, percent                    5.50     11.30
# American Indian and Alaska Native alone, percent            0.70      1.10
# Asian alone, percent                                       35.90     31.10
# Native Hawaiian and Other Pacific Islander alon...          0.40      1.00
# Two or More Races, percent                                  4.30      5.30
# Hispanic or Latino, percent                                15.20     22.50
# White alone, not Hispanic or Latino, percent               40.50     31.50
# Veterans, 2013-2017                                        24582     53532
# Foreign born persons, percent, 2013-2017                   34.80     32.10
# Housing units,  July 1, 2017,  (V2017)                    397550    606052
# Owner-occupied housing unit rate, 2013-2017                37.30     53.00
# Median value of owner-occupied housing units, 2...       927400    649100
# Median selected monthly owner costs -with a mor...         3332      2675
# Median selected monthly owner costs -without a ...          615       608
# Median gross rent, 2013-2017                               1709      1547
# Building permits, 2017                                      4034      9258
# Households, 2013-2017                                     358772    569070
# Persons per household, 2013-2017                            2.35      2.81
# Living in same house 1 year ago, percent of per...         85.60     86.40
# Language other than English spoken at home, per...         43.80     44.60
# Households with a computer, percent, 2013-2017             90.80     92.50
# ...                                                          ...       ...
# Bachelor's degree or higher, percent of persons...         55.80     44.70
# With a disability, under age 65 years, percent,...          6.10      6.10
# Persons  without health insurance, under age 65...          4.70      5.30
# In civilian labor force, total, percent of popu...         70.30     66.60
# In civilian labor force, female, percent of pop...         66.20     60.60
# Total accommodation and food services sales, 20...       6142745   3192420
# Total health care and social assistance receipt...      10175813  12949087
# Total manufacturers shipments, 2012 ($1,000)                   D         D
# Total merchant wholesaler sales, 2012 ($1,000)          11121715  37580614
# Total retail sales, 2012 ($1,000)                       14632652  20901014
# Total retail sales per capita, 2012                       17718     13444
# Mean travel time to work (minutes), workers age...          32.8      32.5
# Median household income (in 2017 dollars), 2013...        96265     85743
# Per capita income in past 12 months (in 2017 do...        59508     41363
# Persons in poverty, percent                                10.10      9.30
# Total employer establishments, 2016                        34314     39242
# Total employment, 2016                                    627915    662511
# Total annual payroll, 2016 ($1,000)                     60475855  45907712
# Total employment, percent change, 2015-2016                 2.70      3.20
# Total nonemployer establishments, 2016                     99307    143612
# All firms, 2012                                           116803    150564
# Men-owned firms, 2012                                      63864     76387
# Women-owned firms, 2012                                    40135     57305
# Minority-owned firms, 2012                                 46128     75026
# Nonminority-owned firms, 2012                              64708     69300
# Veteran-owned firms, 2012                                   6378     10213
# Nonveteran-owned firms, 2012                              104957    134032
# Population per square mile, 2010                        17179.10   2043.60
# Land area in square miles, 2010                            46.87    739.02
# FIPS Code                                                  06075     06001
#
#                                                    San Mateo Contra Costa  \
# Fact
# Population estimates, July 1, 2017,  (V2017)          771410      1147439
# Population estimates base, April 1, 2010,  (V2017)    718500      1049200
# Population, percent change - April 1, 2010 (est...      7.40         9.40
# Population, Census, April 1, 2010                     718451      1049025
# Persons under 5 years, percent                          5.70         5.70
# Persons under 18 years, percent                        20.80        22.80
# Persons 65 years and over, percent                     15.80        15.30
# Female persons, percent                                50.70        51.10
# White alone, percent                                   60.60        65.90
# Black or African American alone, percent                2.80         9.50
# American Indian and Alaska Native alone, percent        0.80         1.00
# Asian alone, percent                                   29.60        17.70
# Native Hawaiian and Other Pacific Islander alon...      1.50         0.60
# Two or More Races, percent                              4.60         5.30
# Hispanic or Latino, percent                            24.50        25.70
# White alone, not Hispanic or Latino, percent           39.30        43.80
# Veterans, 2013-2017                                    26279        49218
# Foreign born persons, percent, 2013-2017               34.70        24.70
# Housing units,  July 1, 2017,  (V2017)                278074       414007
# Owner-occupied housing unit rate, 2013-2017            59.70        65.50
# Median value of owner-occupied housing units, 2...   917700       522300
# Median selected monthly owner costs -with a mor...     3227         2527
# Median selected monthly owner costs -without a ...      689          634
# Median gross rent, 2013-2017                           1973         1600
# Building permits, 2017                                  1582         1984
# Households, 2013-2017                                 261796       389597
# Persons per household, 2013-2017                        2.88         2.86
# Living in same house 1 year ago, percent of per...     87.90        86.60
# Language other than English spoken at home, per...     46.20        34.80
# Households with a computer, percent, 2013-2017         93.70        93.40
# ...                                                      ...          ...
# Bachelor's degree or higher, percent of persons...     48.50        40.70
# With a disability, under age 65 years, percent,...      4.70         7.50
# Persons  without health insurance, under age 65...      5.20         5.90
# In civilian labor force, total, percent of popu...     68.70        64.40
# In civilian labor force, female, percent of pop...     63.10        58.30
# Total accommodation and food services sales, 20...   2552854      1659988
# Total health care and social assistance receipt...   5166992      8262635
# Total manufacturers shipments, 2012 ($1,000)               D     33681206
# Total merchant wholesaler sales, 2012 ($1,000)      15969681      6887164
# Total retail sales, 2012 ($1,000)                   11330620     11847866
# Total retail sales per capita, 2012                   15326        10974
# Mean travel time to work (minutes), workers age...      28.2         37.1
# Median household income (in 2017 dollars), 2013...   105667        88456
# Per capita income in past 12 months (in 2017 do...    53516        42898
# Persons in poverty, percent                             6.40         9.10
# Total employer establishments, 2016                    21199        23591
# Total employment, 2016                                374251       325864
# Total annual payroll, 2016 ($1,000)                 41060198     21468960
# Total employment, percent change, 2015-2016            -0.70         3.30
# Total nonemployer establishments, 2016                 71514        94711
# All firms, 2012                                        75507        93083
# Men-owned firms, 2012                                  39910        47721
# Women-owned firms, 2012                                26594        34296
# Minority-owned firms, 2012                             30914        35831
# Nonminority-owned firms, 2012                          40894        53403
# Veteran-owned firms, 2012                               5141         7291
# Nonveteran-owned firms, 2012                           66645        81940
# Population per square mile, 2010                     1602.20      1465.20
# Land area in square miles, 2010                       448.41       715.94
# FIPS Code                                              06081        06013
#
#                                                    Los Angeles Santa Clara
# Fact
# Population estimates, July 1, 2017,  (V2017)          10163507     1938153
# Population estimates base, April 1, 2010,  (V2017)     9818696     1781671
# Population, percent change - April 1, 2010 (est...        3.50        8.80
# Population, Census, April 1, 2010                      9818605     1781642
# Persons under 5 years, percent                            6.10        6.10
# Persons under 18 years, percent                          21.90       22.20
# Persons 65 years and over, percent                       13.20       13.10
# Female persons, percent                                  50.70       49.50
# White alone, percent                                     70.90       53.80
# Black or African American alone, percent                  9.00        2.80
# American Indian and Alaska Native alone, percent          1.40        1.20
# Asian alone, percent                                     15.30       37.50
# Native Hawaiian and Other Pacific Islander alon...        0.40        0.50
# Two or More Races, percent                                3.00        4.10
# Hispanic or Latino, percent                              48.60       25.60
# White alone, not Hispanic or Latino, percent             26.20       31.60
# Veterans, 2013-2017                                     280109       55763
# Foreign born persons, percent, 2013-2017                 34.40       38.60
# Housing units,  July 1, 2017,  (V2017)                 3542636      671125
# Owner-occupied housing unit rate, 2013-2017              45.90       56.90
# Median value of owner-occupied housing units, 2...     495800      829600
# Median selected monthly owner costs -with a mor...       2336        3081
# Median selected monthly owner costs -without a ...        556         709
# Median gross rent, 2013-2017                             1322        1955
# Building permits, 2017                                   21574        7968
# Households, 2013-2017                                  3295198      630451
# Persons per household, 2013-2017                          3.01        2.98
# Living in same house 1 year ago, percent of per...       88.60       85.40
# Language other than English spoken at home, per...       56.60       52.40
# Households with a computer, percent, 2013-2017           88.70       94.40
# ...                                                        ...         ...
# Bachelor's degree or higher, percent of persons...       31.20       50.00
# With a disability, under age 65 years, percent,...        6.20        4.40
# Persons  without health insurance, under age 65...       10.70        5.10
# In civilian labor force, total, percent of popu...       64.30       67.30
# In civilian labor force, female, percent of pop...       57.80       59.90
# Total accommodation and food services sales, 20...    22965135     4809201
# Total health care and social assistance receipt...    67261267    17020991
# Total manufacturers shipments, 2012 ($1,000)         163829606    41450609
# Total merchant wholesaler sales, 2012 ($1,000)       199804798    91858973
# Total retail sales, 2012 ($1,000)                    121389378    40336741
# Total retail sales per capita, 2012                     12184       21952
# Mean travel time to work (minutes), workers age...        30.9          28
# Median household income (in 2017 dollars), 2013...      61015      106761
# Per capita income in past 12 months (in 2017 do...      30798       48689
# Persons in poverty, percent                              14.90        7.50
# Total employer establishments, 2016                     269489       48278
# Total employment, 2016                                 3871716     1021748
# Total annual payroll, 2016 ($1,000)                  212488786   114930448
# Total employment, percent change, 2015-2016              -3.40        2.20
# Total nonemployer establishments, 2016                 1046426      143480
# All firms, 2012                                        1146701      163130
# Men-owned firms, 2012                                   601676       84501
# Women-owned firms, 2012                                 439513       58589
# Minority-owned firms, 2012                              631218       82931
# Nonminority-owned firms, 2012                           481643       72818
# Veteran-owned firms, 2012                                69608        9400
# Nonveteran-owned firms, 2012                           1044750      146384
# Population per square mile, 2010                       2419.60     1381.00
# Land area in square miles, 2010                        4057.88     1290.10
# FIPS Code                                                06037       06085
#
# [62 rows x 6 columns]

# %%
# convert all objects to numerics
# reference:  https://stackoverflow.com/questions/36814100/pandas-to-numeric-for-multiple-columns
#cols = ca_data.columns[ca_data.dtypes.eq('object')]
clean_ca = ca_data[cols].apply(pd.to_numeric, errors='coerce')
clean_ca.head()
# Out:
#                                                     San Francisco    Alameda  \
# Fact
# Population estimates, July 1, 2017,  (V2017)             884363.0  1663190.0
# Population estimates base, April 1, 2010,  (V2017)       805193.0  1510261.0
# Population, percent change - April 1, 2010 (est...            9.8       10.1
# Population, Census, April 1, 2010                        805235.0  1510271.0
# Persons under 5 years, percent                                4.5        5.9
#
#                                                     San Mateo  Contra Costa  \
# Fact
# Population estimates, July 1, 2017,  (V2017)         771410.0     1147439.0
# Population estimates base, April 1, 2010,  (V2017)   718500.0     1049200.0
# Population, percent change - April 1, 2010 (est...        7.4           9.4
# Population, Census, April 1, 2010                    718451.0     1049025.0
# Persons under 5 years, percent                            5.7           5.7
#
#                                                     Los Angeles  Santa Clara
# Fact
# Population estimates, July 1, 2017,  (V2017)         10163507.0    1938153.0
# Population estimates base, April 1, 2010,  (V2017)    9818696.0    1781671.0
# Population, percent change - April 1, 2010 (est...          3.5          8.8
# Population, Census, April 1, 2010                     9818605.0    1781642.0
# Persons under 5 years, percent                              6.1          6.1

# %%
# Remove extraneous rows, keep only the row you want -- Median Wages
wages = clean_ca[44:45]

#clean_ca.rename({"Median household income (in 2017 dollars), 2013-2017":"Median Income $"},axis=1)

wages
# Out:
#                                                     San Francisco  Alameda  \
# Fact
# Median household income (in 2017 dollars), 2013...        96265.0  85743.0
#
#                                                     San Mateo  Contra Costa  \
# Fact
# Median household income (in 2017 dollars), 2013...   105667.0       88456.0
#
#                                                     Los Angeles  Santa Clara
# Fact
# Median household income (in 2017 dollars), 2013...      61015.0     106761.0

# %%
# Now setup x and y axes for the bar plot

x_data = wages.columns.tolist()   #  x_data has the list of counties to be plotted
x_axis = np.arange(len(x_data))

print(x_data)            # Check that this is a list of counties
print(wages.values[0])   # this is accessing the first (and only) row of data


median_wage = wages.values[0]    #  [[1,2,3,4,5]] ->  row zero [0] [1,2,3,4,5]
# Out:
# ['San Francisco', 'Alameda', 'San Mateo', 'Contra Costa', 'Los Angeles', 'Santa Clara']
# [ 96265.  85743. 105667.  88456.  61015. 106761.]

# %%
plt.bar(x_axis, median_wage, alpha=0.5, align="center")

tick_locations = [value for value in x_axis]
#print(tick_locations)

plt.xticks(tick_locations, x_data, rotation="35", ha='right')   #ha indicates the alignment of the xlabel with the tick mark
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(median_wage) + 20000)
plt.title("Median Wages for People Leaving San Francisco County")
plt.xlabel("Comparison between SF and Top 5 CA counties")
plt.ylabel("Median Salary, ($)")

# Add labels to give more context 

style = dict(size=8, color ='black')
plt.text(0.3,120000, "US Census 2013-2017, All data shown in 2017 dollars", **style)
#plt.text(1,-70000, "All data shown in 2017 dollars", **style)
# Out:
# Text(0.3,120000,'US Census 2013-2017, All data shown in 2017 dollars')

# %%
non_ca_df = non_CA_counties.rename(columns={"San Francisco County, California":"San Francisco",
                                 "New York County (Manhattan Borough), New York":"NY (Manhattan), NY",
                                 "King County, Washington":"King, WA",
                                "Multnomah County, Oregon":"Multnomah, OR",
                                "Kings County (Brooklyn Borough), New York":"Kings (Brooklyn), NY",
                                "Cook County, Illinois":"Cook, IL",
                                "Travis County, Texas":"Travis, TX"
                                            })

# Move the Facts into the index to get it out of the way since we don't need to clean the numbers in that column
# Making a new DF ca_data,  so  you can always refer to ca_df to see the line number of the row
non_ca_data = non_CA_counties.set_index("Fact")

# Clean the $ and % and " signs from multiple columns, first put the columns put them in a list
# Reference:  https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python

cols = non_ca_data.columns

# pass cols to df.replace(), specifying $,%" and , to be replaced by blanks

non_ca_data[cols] = non_ca_data[cols].replace({'\$': '', ',': '', '\%':'', '\"': ''}, regex=True)

non_ca_data
# Out:
#                                                    San Francisco County, California  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                                 884363
# Population estimates base, April 1, 2010,  (V2017)                           805193
# Population, percent change - April 1, 2010 (est...                             9.80
# Population, Census, April 1, 2010                                            805235
# Persons under 5 years, percent                                                 4.50
# Persons under 18 years, percent                                               13.40
# Persons 65 years and over, percent                                            15.40
# Female persons, percent                                                       49.00
# White alone, percent                                                          53.10
# Black or African American alone, percent                                       5.50
# American Indian and Alaska Native alone, percent                               0.70
# Asian alone, percent                                                          35.90
# Native Hawaiian and Other Pacific Islander alon...                             0.40
# Two or More Races, percent                                                     4.30
# Hispanic or Latino, percent                                                   15.20
# White alone, not Hispanic or Latino, percent                                  40.50
# Veterans, 2013-2017                                                           24582
# Foreign born persons, percent, 2013-2017                                      34.80
# Housing units,  July 1, 2017,  (V2017)                                       397550
# Owner-occupied housing unit rate, 2013-2017                                   37.30
# Median value of owner-occupied housing units, 2...                          927400
# Median selected monthly owner costs -with a mor...                            3332
# Median selected monthly owner costs -without a ...                             615
# Median gross rent, 2013-2017                                                  1709
# Building permits, 2017                                                         4034
# Households, 2013-2017                                                        358772
# Persons per household, 2013-2017                                               2.35
# Living in same house 1 year ago, percent of per...                            85.60
# Language other than English spoken at home, per...                            43.80
# Households with a computer, percent, 2013-2017                                90.80
# ...                                                                             ...
# Bachelor's degree or higher, percent of persons...                            55.80
# With a disability, under age 65 years, percent,...                             6.10
# Persons  without health insurance, under age 65...                             4.70
# In civilian labor force, total, percent of popu...                            70.30
# In civilian labor force, female, percent of pop...                            66.20
# Total accommodation and food services sales, 20...                          6142745
# Total health care and social assistance receipt...                         10175813
# Total manufacturers shipments, 2012 ($1,000)                                      D
# Total merchant wholesaler sales, 2012 ($1,000)                             11121715
# Total retail sales, 2012 ($1,000)                                          14632652
# Total retail sales per capita, 2012                                          17718
# Mean travel time to work (minutes), workers age...                             32.8
# Median household income (in 2017 dollars), 2013...                           96265
# Per capita income in past 12 months (in 2017 do...                           59508
# Persons in poverty, percent                                                   10.10
# Total employer establishments, 2016                                           34314
# Total employment, 2016                                                       627915
# Total annual payroll, 2016 ($1,000)                                        60475855
# Total employment, percent change, 2015-2016                                    2.70
# Total nonemployer establishments, 2016                                        99307
# All firms, 2012                                                              116803
# Men-owned firms, 2012                                                         63864
# Women-owned firms, 2012                                                       40135
# Minority-owned firms, 2012                                                    46128
# Nonminority-owned firms, 2012                                                 64708
# Veteran-owned firms, 2012                                                      6378
# Nonveteran-owned firms, 2012                                                 104957
# Population per square mile, 2010                                           17179.10
# Land area in square miles, 2010                                               46.87
# FIPS Code                                                                     06075
#
#                                                    New York County (Manhattan Borough), New York  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                                             1664727
# Population estimates base, April 1, 2010,  (V2017)                                       1586184
# Population, percent change - April 1, 2010 (est...                                          5.00
# Population, Census, April 1, 2010                                                        1585873
# Persons under 5 years, percent                                                              4.80
# Persons under 18 years, percent                                                            14.40
# Persons 65 years and over, percent                                                         16.00
# Female persons, percent                                                                    52.60
# White alone, percent                                                                       64.40
# Black or African American alone, percent                                                   17.90
# American Indian and Alaska Native alone, percent                                            1.20
# Asian alone, percent                                                                       13.00
# Native Hawaiian and Other Pacific Islander alon...                                          0.20
# Two or More Races, percent                                                                  3.40
# Hispanic or Latino, percent                                                                26.10
# White alone, not Hispanic or Latino, percent                                               46.70
# Veterans, 2013-2017                                                                        32192
# Foreign born persons, percent, 2013-2017                                                   28.90
# Housing units,  July 1, 2017,  (V2017)                                                    886408
# Owner-occupied housing unit rate, 2013-2017                                                24.10
# Median value of owner-occupied housing units, 2...                                       915300
# Median selected monthly owner costs -with a mor...                                         3112
# Median selected monthly owner costs -without a ...                                          946
# Median gross rent, 2013-2017                                                               1615
# Building permits, 2017                                                                      4781
# Households, 2013-2017                                                                     758345
# Persons per household, 2013-2017                                                             2.1
# Living in same house 1 year ago, percent of per...                                         84.60
# Language other than English spoken at home, per...                                         40.00
# Households with a computer, percent, 2013-2017                                             89.10
# ...                                                                                          ...
# Bachelor's degree or higher, percent of persons...                                         60.70
# With a disability, under age 65 years, percent,...                                          6.00
# Persons  without health insurance, under age 65...                                          6.30
# In civilian labor force, total, percent of popu...                                         67.20
# In civilian labor force, female, percent of pop...                                         62.40
# Total accommodation and food services sales, 20...                                      20382622
# Total health care and social assistance receipt...                                      34680452
# Total manufacturers shipments, 2012 ($1,000)                                             4970920
# Total merchant wholesaler sales, 2012 ($1,000)                                         128760891
# Total retail sales, 2012 ($1,000)                                                       44039957
# Total retail sales per capita, 2012                                                       27200
# Mean travel time to work (minutes), workers age...                                          31.8
# Median household income (in 2017 dollars), 2013...                                        79781
# Per capita income in past 12 months (in 2017 do...                                        69529
# Persons in poverty, percent                                                                16.30
# Total employer establishments, 2016                                                       104691
# Total employment, 2016                                                                   2245903
# Total annual payroll, 2016 ($1,000)                                                    241159256
# Total employment, percent change, 2015-2016                                                 1.80
# Total nonemployer establishments, 2016                                                    226631
# All firms, 2012                                                                           315399
# Men-owned firms, 2012                                                                     171730
# Women-owned firms, 2012                                                                   114896
# Minority-owned firms, 2012                                                                 99763
# Nonminority-owned firms, 2012                                                             198433
# Veteran-owned firms, 2012                                                                  18120
# Nonveteran-owned firms, 2012                                                              280398
# Population per square mile, 2010                                                        69467.50
# Land area in square miles, 2010                                                            22.83
# FIPS Code                                                                                  36061
#
#                                                    King County, Washington  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                       2188649
# Population estimates base, April 1, 2010,  (V2017)                 1931281
# Population, percent change - April 1, 2010 (est...                   13.30
# Population, Census, April 1, 2010                                  1931249
# Persons under 5 years, percent                                        5.90
# Persons under 18 years, percent                                      20.40
# Persons 65 years and over, percent                                   13.00
# Female persons, percent                                              49.90
# White alone, percent                                                 68.00
# Black or African American alone, percent                              6.80
# American Indian and Alaska Native alone, percent                      1.00
# Asian alone, percent                                                 18.20
# Native Hawaiian and Other Pacific Islander alon...                    0.90
# Two or More Races, percent                                            5.10
# Hispanic or Latino, percent                                           9.70
# White alone, not Hispanic or Latino, percent                         60.00
# Veterans, 2013-2017                                                 106384
# Foreign born persons, percent, 2013-2017                             22.10
# Housing units,  July 1, 2017,  (V2017)                              934552
# Owner-occupied housing unit rate, 2013-2017                          57.40
# Median value of owner-occupied housing units, 2...                 446600
# Median selected monthly owner costs -with a mor...                   2271
# Median selected monthly owner costs -without a ...                    732
# Median gross rent, 2013-2017                                         1379
# Building permits, 2017                                               18641
# Households, 2013-2017                                               851077
# Persons per household, 2013-2017                                      2.45
# Living in same house 1 year ago, percent of per...                   81.00
# Language other than English spoken at home, per...                   26.70
# Households with a computer, percent, 2013-2017                       94.00
# ...                                                                    ...
# Bachelor's degree or higher, percent of persons...                   50.30
# With a disability, under age 65 years, percent,...                    6.40
# Persons  without health insurance, under age 65...                    5.60
# In civilian labor force, total, percent of popu...                   69.50
# In civilian labor force, female, percent of pop...                   63.40
# Total accommodation and food services sales, 20...                 6223768
# Total health care and social assistance receipt...                17719220
# Total manufacturers shipments, 2012 ($1,000)                             D
# Total merchant wholesaler sales, 2012 ($1,000)                    42092462
# Total retail sales, 2012 ($1,000)                                 61598157
# Total retail sales per capita, 2012                                 30685
# Mean travel time to work (minutes), workers age...                    29.1
# Median household income (in 2017 dollars), 2013...                  83571
# Per capita income in past 12 months (in 2017 do...                  46316
# Persons in poverty, percent                                           9.30
# Total employer establishments, 2016                                  68079
# Total employment, 2016                                             1167201
# Total annual payroll, 2016 ($1,000)                               87675700
# Total employment, percent change, 2015-2016                           3.00
# Total nonemployer establishments, 2016                              172297
# All firms, 2012                                                     201404
# Men-owned firms, 2012                                               100912
# Women-owned firms, 2012                                              71005
# Minority-owned firms, 2012                                           45508
# Nonminority-owned firms, 2012                                       145726
# Veteran-owned firms, 2012                                            15016
# Nonveteran-owned firms, 2012                                        175951
# Population per square mile, 2010                                     912.9
# Land area in square miles, 2010                                    2115.57
# FIPS Code                                                            53033
#
#                                                    Multnomah County, Oregon  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                         807555
# Population estimates base, April 1, 2010,  (V2017)                   735169
# Population, percent change - April 1, 2010 (est...                     9.80
# Population, Census, April 1, 2010                                    735334
# Persons under 5 years, percent                                         5.60
# Persons under 18 years, percent                                       19.10
# Persons 65 years and over, percent                                    13.00
# Female persons, percent                                               50.50
# White alone, percent                                                  79.50
# Black or African American alone, percent                               6.00
# American Indian and Alaska Native alone, percent                       1.40
# Asian alone, percent                                                   7.90
# Native Hawaiian and Other Pacific Islander alon...                     0.70
# Two or More Races, percent                                             4.60
# Hispanic or Latino, percent                                           11.60
# White alone, not Hispanic or Latino, percent                          69.90
# Veterans, 2013-2017                                                   39407
# Foreign born persons, percent, 2013-2017                              14.20
# Housing units,  July 1, 2017,  (V2017)                               347077
# Owner-occupied housing unit rate, 2013-2017                           54.30
# Median value of owner-occupied housing units, 2...                  330900
# Median selected monthly owner costs -with a mor...                    1799
# Median selected monthly owner costs -without a ...                     616
# Median gross rent, 2013-2017                                          1094
# Building permits, 2017                                                 7055
# Households, 2013-2017                                                318173
# Persons per household, 2013-2017                                       2.42
# Living in same house 1 year ago, percent of per...                    80.80
# Language other than English spoken at home, per...                    20.00
# Households with a computer, percent, 2013-2017                        91.80
# ...                                                                     ...
# Bachelor's degree or higher, percent of persons...                    43.80
# With a disability, under age 65 years, percent,...                     9.80
# Persons  without health insurance, under age 65...                     7.30
# In civilian labor force, total, percent of popu...                    68.80
# In civilian labor force, female, percent of pop...                    65.00
# Total accommodation and food services sales, 20...                  2506213
# Total health care and social assistance receipt...                  7703673
# Total manufacturers shipments, 2012 ($1,000)                       10278074
# Total merchant wholesaler sales, 2012 ($1,000)                     21267780
# Total retail sales, 2012 ($1,000)                                   9982933
# Total retail sales per capita, 2012                                  13148
# Mean travel time to work (minutes), workers age...                     26.6
# Median household income (in 2017 dollars), 2013...                   60369
# Per capita income in past 12 months (in 2017 do...                   34848
# Persons in poverty, percent                                           14.40
# Total employer establishments, 2016                                   27246
# Total employment, 2016                                               434205
# Total annual payroll, 2016 ($1,000)                                22672822
# Total employment, percent change, 2015-2016                            3.80
# Total nonemployer establishments, 2016                                71087
# All firms, 2012                                                       85366
# Men-owned firms, 2012                                                 42283
# Women-owned firms, 2012                                               33046
# Minority-owned firms, 2012                                            13825
# Nonminority-owned firms, 2012                                         67269
# Veteran-owned firms, 2012                                              6676
# Nonveteran-owned firms, 2012                                          74013
# Population per square mile, 2010                                    1704.90
# Land area in square miles, 2010                                       431.3
# FIPS Code                                                             41051
#
#                                                    Kings County (Brooklyn Borough), New York  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                                         2648771
# Population estimates base, April 1, 2010,  (V2017)                                   2504706
# Population, percent change - April 1, 2010 (est...                                      5.80
# Population, Census, April 1, 2010                                                    2504700
# Persons under 5 years, percent                                                          7.30
# Persons under 18 years, percent                                                        22.90
# Persons 65 years and over, percent                                                     13.50
# Female persons, percent                                                                52.60
# White alone, percent                                                                   49.20
# Black or African American alone, percent                                               34.30
# American Indian and Alaska Native alone, percent                                        0.90
# Asian alone, percent                                                                   12.80
# Native Hawaiian and Other Pacific Islander alon...                                      0.10
# Two or More Races, percent                                                              2.60
# Hispanic or Latino, percent                                                            19.10
# White alone, not Hispanic or Latino, percent                                           36.10
# Veterans, 2013-2017                                                                    40990
# Foreign born persons, percent, 2013-2017                                               36.90
# Housing units,  July 1, 2017,  (V2017)                                               1044337
# Owner-occupied housing unit rate, 2013-2017                                            30.00
# Median value of owner-occupied housing units, 2...                                   623900
# Median selected monthly owner costs -with a mor...                                     2723
# Median selected monthly owner costs -without a ...                                      843
# Median gross rent, 2013-2017                                                           1314
# Building permits, 2017                                                                  6130
# Households, 2013-2017                                                                 944650
# Persons per household, 2013-2017                                                        2.75
# Living in same house 1 year ago, percent of per...                                     90.60
# Language other than English spoken at home, per...                                     45.90
# Households with a computer, percent, 2013-2017                                         84.10
# ...                                                                                      ...
# Bachelor's degree or higher, percent of persons...                                     35.20
# With a disability, under age 65 years, percent,...                                      6.10
# Persons  without health insurance, under age 65...                                      8.80
# In civilian labor force, total, percent of popu...                                     63.40
# In civilian labor force, female, percent of pop...                                     59.00
# Total accommodation and food services sales, 20...                                   2453405
# Total health care and social assistance receipt...                                  16419598
# Total manufacturers shipments, 2012 ($1,000)                                         3644086
# Total merchant wholesaler sales, 2012 ($1,000)                                      16522942
# Total retail sales, 2012 ($1,000)                                                   20533079
# Total retail sales per capita, 2012                                                    8003
# Mean travel time to work (minutes), workers age...                                      42.4
# Median household income (in 2017 dollars), 2013...                                    52782
# Per capita income in past 12 months (in 2017 do...                                    29928
# Persons in poverty, percent                                                            19.80
# Total employer establishments, 2016                                                    57621
# Total employment, 2016                                                                606738
# Total annual payroll, 2016 ($1,000)                                                 24611877
# Total employment, percent change, 2015-2016                                             4.90
# Total nonemployer establishments, 2016                                                269471
# All firms, 2012                                                                       296858
# Men-owned firms, 2012                                                                 162037
# Women-owned firms, 2012                                                               118489
# Minority-owned firms, 2012                                                            143596
# Nonminority-owned firms, 2012                                                         147926
# Veteran-owned firms, 2012                                                              16236
# Nonveteran-owned firms, 2012                                                          275506
# Population per square mile, 2010                                                    35369.10
# Land area in square miles, 2010                                                        70.82
# FIPS Code                                                                              36047
#
#                                                    Cook County, Illinois  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                     5211263
# Population estimates base, April 1, 2010,  (V2017)               5195075
# Population, percent change - April 1, 2010 (est...                  0.30
# Population, Census, April 1, 2010                                5194675
# Persons under 5 years, percent                                      6.20
# Persons under 18 years, percent                                    22.00
# Persons 65 years and over, percent                                 14.30
# Female persons, percent                                            51.40
# White alone, percent                                               65.60
# Black or African American alone, percent                           24.00
# American Indian and Alaska Native alone, percent                    0.70
# Asian alone, percent                                                7.70
# Native Hawaiian and Other Pacific Islander alon...                  0.10
# Two or More Races, percent                                          1.90
# Hispanic or Latino, percent                                        25.50
# White alone, not Hispanic or Latino, percent                       42.30
# Veterans, 2013-2017                                               172838
# Foreign born persons, percent, 2013-2017                           21.10
# Housing units,  July 1, 2017,  (V2017)                           2193073
# Owner-occupied housing unit rate, 2013-2017                        56.90
# Median value of owner-occupied housing units, 2...               227400
# Median selected monthly owner costs -with a mor...                 1847
# Median selected monthly owner costs -without a ...                  713
# Median gross rent, 2013-2017                                       1044
# Building permits, 2017                                             11595
# Households, 2013-2017                                            1956561
# Persons per household, 2013-2017                                    2.63
# Living in same house 1 year ago, percent of per...                 86.80
# Language other than English spoken at home, per...                 35.10
# Households with a computer, percent, 2013-2017                     85.90
# ...                                                                  ...
# Bachelor's degree or higher, percent of persons...                 37.20
# With a disability, under age 65 years, percent,...                  6.60
# Persons  without health insurance, under age 65...                  9.40
# In civilian labor force, total, percent of popu...                 65.80
# In civilian labor force, female, percent of pop...                 60.60
# Total accommodation and food services sales, 20...              14553105
# Total health care and social assistance receipt...              39639868
# Total manufacturers shipments, 2012 ($1,000)                    79526980
# Total merchant wholesaler sales, 2012 ($1,000)                 100829550
# Total retail sales, 2012 ($1,000)                               62767358
# Total retail sales per capita, 2012                               11998
# Mean travel time to work (minutes), workers age...                  32.9
# Median household income (in 2017 dollars), 2013...                59426
# Per capita income in past 12 months (in 2017 do...                33722
# Persons in poverty, percent                                        14.60
# Total employer establishments, 2016                               133150
# Total employment, 2016                                           2401662
# Total annual payroll, 2016 ($1,000)                            145680137
# Total employment, percent change, 2015-2016                         1.70
# Total nonemployer establishments, 2016                            483757
# All firms, 2012                                                   549686
# Men-owned firms, 2012                                             291278
# Women-owned firms, 2012                                           216929
# Minority-owned firms, 2012                                        216374
# Nonminority-owned firms, 2012                                     319115
# Veteran-owned firms, 2012                                          38665
# Nonveteran-owned firms, 2012                                      495450
# Population per square mile, 2010                                 5495.10
# Land area in square miles, 2010                                   945.33
# FIPS Code                                                          17031
#
#                                                    Travis County, Texas
# Fact
# Population estimates, July 1, 2017,  (V2017)                    1226698
# Population estimates base, April 1, 2010,  (V2017)              1024479
# Population, percent change - April 1, 2010 (est...                19.70
# Population, Census, April 1, 2010                               1024266
# Persons under 5 years, percent                                     6.50
# Persons under 18 years, percent                                   22.10
# Persons 65 years and over, percent                                 9.60
# Female persons, percent                                           49.50
# White alone, percent                                              80.20
# Black or African American alone, percent                           8.90
# American Indian and Alaska Native alone, percent                   1.20
# Asian alone, percent                                               7.10
# Native Hawaiian and Other Pacific Islander alon...                 0.10
# Two or More Races, percent                                         2.60
# Hispanic or Latino, percent                                       33.90
# White alone, not Hispanic or Latino, percent                      49.00
# Veterans, 2013-2017                                               51893
# Foreign born persons, percent, 2013-2017                          17.80
# Housing units,  July 1, 2017,  (V2017)                           512388
# Owner-occupied housing unit rate, 2013-2017                       52.30
# Median value of owner-occupied housing units, 2...              275800
# Median selected monthly owner costs -with a mor...                1851
# Median selected monthly owner costs -without a ...                 719
# Median gross rent, 2013-2017                                      1172
# Building permits, 2017                                            16729
# Households, 2013-2017                                            447561
# Persons per household, 2013-2017                                   2.58
# Living in same house 1 year ago, percent of per...                80.50
# Language other than English spoken at home, per...                31.60
# Households with a computer, percent, 2013-2017                    93.10
# ...                                                                 ...
# Bachelor's degree or higher, percent of persons...                47.50
# With a disability, under age 65 years, percent,...                 6.40
# Persons  without health insurance, under age 65...                15.20
# In civilian labor force, total, percent of popu...                72.30
# In civilian labor force, female, percent of pop...                65.60
# Total accommodation and food services sales, 20...              3726774
# Total health care and social assistance receipt...              6996844
# Total manufacturers shipments, 2012 ($1,000)                   12281855
# Total merchant wholesaler sales, 2012 ($1,000)                 56614786
# Total retail sales, 2012 ($1,000)                              15583650
# Total retail sales per capita, 2012                              14224
# Mean travel time to work (minutes), workers age...                 25.3
# Median household income (in 2017 dollars), 2013...               68350
# Per capita income in past 12 months (in 2017 do...               38820
# Persons in poverty, percent                                       11.50
# Total employer establishments, 2016                               34547
# Total employment, 2016                                           582889
# Total annual payroll, 2016 ($1,000)                            34479460
# Total employment, percent change, 2015-2016                        3.50
# Total nonemployer establishments, 2016                           118984
# All firms, 2012                                                  120533
# Men-owned firms, 2012                                             64679
# Women-owned firms, 2012                                           42186
# Minority-owned firms, 2012                                        35323
# Nonminority-owned firms, 2012                                     79883
# Veteran-owned firms, 2012                                          9520
# Nonveteran-owned firms, 2012                                     105236
# Population per square mile, 2010                                1034.40
# Land area in square miles, 2010                                   990.2
# FIPS Code                                                         48453
#
# [62 rows x 7 columns]

# %%
# convert all objects to numerics
# reference:  https://stackoverflow.com/questions/36814100/pandas-to-numeric-for-multiple-columns
#cols = ca_data.columns[ca_data.dtypes.eq('object')]
non_ca_data = non_ca_data[cols].apply(pd.to_numeric, errors='coerce')
non_ca_data
# Out:
#                                                     San Francisco County, California  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                               884363.00
# Population estimates base, April 1, 2010,  (V2017)                         805193.00
# Population, percent change - April 1, 2010 (est...                              9.80
# Population, Census, April 1, 2010                                          805235.00
# Persons under 5 years, percent                                                  4.50
# Persons under 18 years, percent                                                13.40
# Persons 65 years and over, percent                                             15.40
# Female persons, percent                                                        49.00
# White alone, percent                                                           53.10
# Black or African American alone, percent                                        5.50
# American Indian and Alaska Native alone, percent                                0.70
# Asian alone, percent                                                           35.90
# Native Hawaiian and Other Pacific Islander alon...                              0.40
# Two or More Races, percent                                                      4.30
# Hispanic or Latino, percent                                                    15.20
# White alone, not Hispanic or Latino, percent                                   40.50
# Veterans, 2013-2017                                                         24582.00
# Foreign born persons, percent, 2013-2017                                       34.80
# Housing units,  July 1, 2017,  (V2017)                                     397550.00
# Owner-occupied housing unit rate, 2013-2017                                    37.30
# Median value of owner-occupied housing units, 2...                         927400.00
# Median selected monthly owner costs -with a mor...                           3332.00
# Median selected monthly owner costs -without a ...                            615.00
# Median gross rent, 2013-2017                                                 1709.00
# Building permits, 2017                                                       4034.00
# Households, 2013-2017                                                      358772.00
# Persons per household, 2013-2017                                                2.35
# Living in same house 1 year ago, percent of per...                             85.60
# Language other than English spoken at home, per...                             43.80
# Households with a computer, percent, 2013-2017                                 90.80
# ...                                                                              ...
# Bachelor's degree or higher, percent of persons...                             55.80
# With a disability, under age 65 years, percent,...                              6.10
# Persons  without health insurance, under age 65...                              4.70
# In civilian labor force, total, percent of popu...                             70.30
# In civilian labor force, female, percent of pop...                             66.20
# Total accommodation and food services sales, 20...                        6142745.00
# Total health care and social assistance receipt...                       10175813.00
# Total manufacturers shipments, 2012 ($1,000)                                     NaN
# Total merchant wholesaler sales, 2012 ($1,000)                           11121715.00
# Total retail sales, 2012 ($1,000)                                        14632652.00
# Total retail sales per capita, 2012                                         17718.00
# Mean travel time to work (minutes), workers age...                             32.80
# Median household income (in 2017 dollars), 2013...                          96265.00
# Per capita income in past 12 months (in 2017 do...                          59508.00
# Persons in poverty, percent                                                    10.10
# Total employer establishments, 2016                                         34314.00
# Total employment, 2016                                                     627915.00
# Total annual payroll, 2016 ($1,000)                                      60475855.00
# Total employment, percent change, 2015-2016                                     2.70
# Total nonemployer establishments, 2016                                      99307.00
# All firms, 2012                                                            116803.00
# Men-owned firms, 2012                                                       63864.00
# Women-owned firms, 2012                                                     40135.00
# Minority-owned firms, 2012                                                  46128.00
# Nonminority-owned firms, 2012                                               64708.00
# Veteran-owned firms, 2012                                                    6378.00
# Nonveteran-owned firms, 2012                                               104957.00
# Population per square mile, 2010                                            17179.10
# Land area in square miles, 2010                                                46.87
# FIPS Code                                                                    6075.00
#
#                                                     New York County (Manhattan Borough), New York  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                                         1.664727e+06
# Population estimates base, April 1, 2010,  (V2017)                                   1.586184e+06
# Population, percent change - April 1, 2010 (est...                                   5.000000e+00
# Population, Census, April 1, 2010                                                    1.585873e+06
# Persons under 5 years, percent                                                       4.800000e+00
# Persons under 18 years, percent                                                      1.440000e+01
# Persons 65 years and over, percent                                                   1.600000e+01
# Female persons, percent                                                              5.260000e+01
# White alone, percent                                                                 6.440000e+01
# Black or African American alone, percent                                             1.790000e+01
# American Indian and Alaska Native alone, percent                                     1.200000e+00
# Asian alone, percent                                                                 1.300000e+01
# Native Hawaiian and Other Pacific Islander alon...                                   2.000000e-01
# Two or More Races, percent                                                           3.400000e+00
# Hispanic or Latino, percent                                                          2.610000e+01
# White alone, not Hispanic or Latino, percent                                         4.670000e+01
# Veterans, 2013-2017                                                                  3.219200e+04
# Foreign born persons, percent, 2013-2017                                             2.890000e+01
# Housing units,  July 1, 2017,  (V2017)                                               8.864080e+05
# Owner-occupied housing unit rate, 2013-2017                                          2.410000e+01
# Median value of owner-occupied housing units, 2...                                   9.153000e+05
# Median selected monthly owner costs -with a mor...                                   3.112000e+03
# Median selected monthly owner costs -without a ...                                   9.460000e+02
# Median gross rent, 2013-2017                                                         1.615000e+03
# Building permits, 2017                                                               4.781000e+03
# Households, 2013-2017                                                                7.583450e+05
# Persons per household, 2013-2017                                                     2.100000e+00
# Living in same house 1 year ago, percent of per...                                   8.460000e+01
# Language other than English spoken at home, per...                                   4.000000e+01
# Households with a computer, percent, 2013-2017                                       8.910000e+01
# ...                                                                                           ...
# Bachelor's degree or higher, percent of persons...                                   6.070000e+01
# With a disability, under age 65 years, percent,...                                   6.000000e+00
# Persons  without health insurance, under age 65...                                   6.300000e+00
# In civilian labor force, total, percent of popu...                                   6.720000e+01
# In civilian labor force, female, percent of pop...                                   6.240000e+01
# Total accommodation and food services sales, 20...                                   2.038262e+07
# Total health care and social assistance receipt...                                   3.468045e+07
# Total manufacturers shipments, 2012 ($1,000)                                         4.970920e+06
# Total merchant wholesaler sales, 2012 ($1,000)                                       1.287609e+08
# Total retail sales, 2012 ($1,000)                                                    4.403996e+07
# Total retail sales per capita, 2012                                                  2.720000e+04
# Mean travel time to work (minutes), workers age...                                   3.180000e+01
# Median household income (in 2017 dollars), 2013...                                   7.978100e+04
# Per capita income in past 12 months (in 2017 do...                                   6.952900e+04
# Persons in poverty, percent                                                          1.630000e+01
# Total employer establishments, 2016                                                  1.046910e+05
# Total employment, 2016                                                               2.245903e+06
# Total annual payroll, 2016 ($1,000)                                                  2.411593e+08
# Total employment, percent change, 2015-2016                                          1.800000e+00
# Total nonemployer establishments, 2016                                               2.266310e+05
# All firms, 2012                                                                      3.153990e+05
# Men-owned firms, 2012                                                                1.717300e+05
# Women-owned firms, 2012                                                              1.148960e+05
# Minority-owned firms, 2012                                                           9.976300e+04
# Nonminority-owned firms, 2012                                                        1.984330e+05
# Veteran-owned firms, 2012                                                            1.812000e+04
# Nonveteran-owned firms, 2012                                                         2.803980e+05
# Population per square mile, 2010                                                     6.946750e+04
# Land area in square miles, 2010                                                      2.283000e+01
# FIPS Code                                                                            3.606100e+04
#
#                                                     King County, Washington  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                     2188649.00
# Population estimates base, April 1, 2010,  (V2017)               1931281.00
# Population, percent change - April 1, 2010 (est...                    13.30
# Population, Census, April 1, 2010                                1931249.00
# Persons under 5 years, percent                                         5.90
# Persons under 18 years, percent                                       20.40
# Persons 65 years and over, percent                                    13.00
# Female persons, percent                                               49.90
# White alone, percent                                                  68.00
# Black or African American alone, percent                               6.80
# American Indian and Alaska Native alone, percent                       1.00
# Asian alone, percent                                                  18.20
# Native Hawaiian and Other Pacific Islander alon...                     0.90
# Two or More Races, percent                                             5.10
# Hispanic or Latino, percent                                            9.70
# White alone, not Hispanic or Latino, percent                          60.00
# Veterans, 2013-2017                                               106384.00
# Foreign born persons, percent, 2013-2017                              22.10
# Housing units,  July 1, 2017,  (V2017)                            934552.00
# Owner-occupied housing unit rate, 2013-2017                           57.40
# Median value of owner-occupied housing units, 2...                446600.00
# Median selected monthly owner costs -with a mor...                  2271.00
# Median selected monthly owner costs -without a ...                   732.00
# Median gross rent, 2013-2017                                        1379.00
# Building permits, 2017                                             18641.00
# Households, 2013-2017                                             851077.00
# Persons per household, 2013-2017                                       2.45
# Living in same house 1 year ago, percent of per...                    81.00
# Language other than English spoken at home, per...                    26.70
# Households with a computer, percent, 2013-2017                        94.00
# ...                                                                     ...
# Bachelor's degree or higher, percent of persons...                    50.30
# With a disability, under age 65 years, percent,...                     6.40
# Persons  without health insurance, under age 65...                     5.60
# In civilian labor force, total, percent of popu...                    69.50
# In civilian labor force, female, percent of pop...                    63.40
# Total accommodation and food services sales, 20...               6223768.00
# Total health care and social assistance receipt...              17719220.00
# Total manufacturers shipments, 2012 ($1,000)                            NaN
# Total merchant wholesaler sales, 2012 ($1,000)                  42092462.00
# Total retail sales, 2012 ($1,000)                               61598157.00
# Total retail sales per capita, 2012                                30685.00
# Mean travel time to work (minutes), workers age...                    29.10
# Median household income (in 2017 dollars), 2013...                 83571.00
# Per capita income in past 12 months (in 2017 do...                 46316.00
# Persons in poverty, percent                                            9.30
# Total employer establishments, 2016                                68079.00
# Total employment, 2016                                           1167201.00
# Total annual payroll, 2016 ($1,000)                             87675700.00
# Total employment, percent change, 2015-2016                            3.00
# Total nonemployer establishments, 2016                            172297.00
# All firms, 2012                                                   201404.00
# Men-owned firms, 2012                                             100912.00
# Women-owned firms, 2012                                            71005.00
# Minority-owned firms, 2012                                         45508.00
# Nonminority-owned firms, 2012                                     145726.00
# Veteran-owned firms, 2012                                          15016.00
# Nonveteran-owned firms, 2012                                      175951.00
# Population per square mile, 2010                                     912.90
# Land area in square miles, 2010                                     2115.57
# FIPS Code                                                          53033.00
#
#                                                     Multnomah County, Oregon  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                       807555.00
# Population estimates base, April 1, 2010,  (V2017)                 735169.00
# Population, percent change - April 1, 2010 (est...                      9.80
# Population, Census, April 1, 2010                                  735334.00
# Persons under 5 years, percent                                          5.60
# Persons under 18 years, percent                                        19.10
# Persons 65 years and over, percent                                     13.00
# Female persons, percent                                                50.50
# White alone, percent                                                   79.50
# Black or African American alone, percent                                6.00
# American Indian and Alaska Native alone, percent                        1.40
# Asian alone, percent                                                    7.90
# Native Hawaiian and Other Pacific Islander alon...                      0.70
# Two or More Races, percent                                              4.60
# Hispanic or Latino, percent                                            11.60
# White alone, not Hispanic or Latino, percent                           69.90
# Veterans, 2013-2017                                                 39407.00
# Foreign born persons, percent, 2013-2017                               14.20
# Housing units,  July 1, 2017,  (V2017)                             347077.00
# Owner-occupied housing unit rate, 2013-2017                            54.30
# Median value of owner-occupied housing units, 2...                 330900.00
# Median selected monthly owner costs -with a mor...                   1799.00
# Median selected monthly owner costs -without a ...                    616.00
# Median gross rent, 2013-2017                                         1094.00
# Building permits, 2017                                               7055.00
# Households, 2013-2017                                              318173.00
# Persons per household, 2013-2017                                        2.42
# Living in same house 1 year ago, percent of per...                     80.80
# Language other than English spoken at home, per...                     20.00
# Households with a computer, percent, 2013-2017                         91.80
# ...                                                                      ...
# Bachelor's degree or higher, percent of persons...                     43.80
# With a disability, under age 65 years, percent,...                      9.80
# Persons  without health insurance, under age 65...                      7.30
# In civilian labor force, total, percent of popu...                     68.80
# In civilian labor force, female, percent of pop...                     65.00
# Total accommodation and food services sales, 20...                2506213.00
# Total health care and social assistance receipt...                7703673.00
# Total manufacturers shipments, 2012 ($1,000)                     10278074.00
# Total merchant wholesaler sales, 2012 ($1,000)                   21267780.00
# Total retail sales, 2012 ($1,000)                                 9982933.00
# Total retail sales per capita, 2012                                 13148.00
# Mean travel time to work (minutes), workers age...                     26.60
# Median household income (in 2017 dollars), 2013...                  60369.00
# Per capita income in past 12 months (in 2017 do...                  34848.00
# Persons in poverty, percent                                            14.40
# Total employer establishments, 2016                                 27246.00
# Total employment, 2016                                             434205.00
# Total annual payroll, 2016 ($1,000)                              22672822.00
# Total employment, percent change, 2015-2016                             3.80
# Total nonemployer establishments, 2016                              71087.00
# All firms, 2012                                                     85366.00
# Men-owned firms, 2012                                               42283.00
# Women-owned firms, 2012                                             33046.00
# Minority-owned firms, 2012                                          13825.00
# Nonminority-owned firms, 2012                                       67269.00
# Veteran-owned firms, 2012                                            6676.00
# Nonveteran-owned firms, 2012                                        74013.00
# Population per square mile, 2010                                     1704.90
# Land area in square miles, 2010                                       431.30
# FIPS Code                                                           41051.00
#
#                                                     Kings County (Brooklyn Borough), New York  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                                       2648771.00
# Population estimates base, April 1, 2010,  (V2017)                                 2504706.00
# Population, percent change - April 1, 2010 (est...                                       5.80
# Population, Census, April 1, 2010                                                  2504700.00
# Persons under 5 years, percent                                                           7.30
# Persons under 18 years, percent                                                         22.90
# Persons 65 years and over, percent                                                      13.50
# Female persons, percent                                                                 52.60
# White alone, percent                                                                    49.20
# Black or African American alone, percent                                                34.30
# American Indian and Alaska Native alone, percent                                         0.90
# Asian alone, percent                                                                    12.80
# Native Hawaiian and Other Pacific Islander alon...                                       0.10
# Two or More Races, percent                                                               2.60
# Hispanic or Latino, percent                                                             19.10
# White alone, not Hispanic or Latino, percent                                            36.10
# Veterans, 2013-2017                                                                  40990.00
# Foreign born persons, percent, 2013-2017                                                36.90
# Housing units,  July 1, 2017,  (V2017)                                             1044337.00
# Owner-occupied housing unit rate, 2013-2017                                             30.00
# Median value of owner-occupied housing units, 2...                                  623900.00
# Median selected monthly owner costs -with a mor...                                    2723.00
# Median selected monthly owner costs -without a ...                                     843.00
# Median gross rent, 2013-2017                                                          1314.00
# Building permits, 2017                                                                6130.00
# Households, 2013-2017                                                               944650.00
# Persons per household, 2013-2017                                                         2.75
# Living in same house 1 year ago, percent of per...                                      90.60
# Language other than English spoken at home, per...                                      45.90
# Households with a computer, percent, 2013-2017                                          84.10
# ...                                                                                       ...
# Bachelor's degree or higher, percent of persons...                                      35.20
# With a disability, under age 65 years, percent,...                                       6.10
# Persons  without health insurance, under age 65...                                       8.80
# In civilian labor force, total, percent of popu...                                      63.40
# In civilian labor force, female, percent of pop...                                      59.00
# Total accommodation and food services sales, 20...                                 2453405.00
# Total health care and social assistance receipt...                                16419598.00
# Total manufacturers shipments, 2012 ($1,000)                                       3644086.00
# Total merchant wholesaler sales, 2012 ($1,000)                                    16522942.00
# Total retail sales, 2012 ($1,000)                                                 20533079.00
# Total retail sales per capita, 2012                                                   8003.00
# Mean travel time to work (minutes), workers age...                                      42.40
# Median household income (in 2017 dollars), 2013...                                   52782.00
# Per capita income in past 12 months (in 2017 do...                                   29928.00
# Persons in poverty, percent                                                             19.80
# Total employer establishments, 2016                                                  57621.00
# Total employment, 2016                                                              606738.00
# Total annual payroll, 2016 ($1,000)                                               24611877.00
# Total employment, percent change, 2015-2016                                              4.90
# Total nonemployer establishments, 2016                                              269471.00
# All firms, 2012                                                                     296858.00
# Men-owned firms, 2012                                                               162037.00
# Women-owned firms, 2012                                                             118489.00
# Minority-owned firms, 2012                                                          143596.00
# Nonminority-owned firms, 2012                                                       147926.00
# Veteran-owned firms, 2012                                                            16236.00
# Nonveteran-owned firms, 2012                                                        275506.00
# Population per square mile, 2010                                                     35369.10
# Land area in square miles, 2010                                                         70.82
# FIPS Code                                                                            36047.00
#
#                                                     Cook County, Illinois  \
# Fact
# Population estimates, July 1, 2017,  (V2017)                 5.211263e+06
# Population estimates base, April 1, 2010,  (V2017)           5.195075e+06
# Population, percent change - April 1, 2010 (est...           3.000000e-01
# Population, Census, April 1, 2010                            5.194675e+06
# Persons under 5 years, percent                               6.200000e+00
# Persons under 18 years, percent                              2.200000e+01
# Persons 65 years and over, percent                           1.430000e+01
# Female persons, percent                                      5.140000e+01
# White alone, percent                                         6.560000e+01
# Black or African American alone, percent                     2.400000e+01
# American Indian and Alaska Native alone, percent             7.000000e-01
# Asian alone, percent                                         7.700000e+00
# Native Hawaiian and Other Pacific Islander alon...           1.000000e-01
# Two or More Races, percent                                   1.900000e+00
# Hispanic or Latino, percent                                  2.550000e+01
# White alone, not Hispanic or Latino, percent                 4.230000e+01
# Veterans, 2013-2017                                          1.728380e+05
# Foreign born persons, percent, 2013-2017                     2.110000e+01
# Housing units,  July 1, 2017,  (V2017)                       2.193073e+06
# Owner-occupied housing unit rate, 2013-2017                  5.690000e+01
# Median value of owner-occupied housing units, 2...           2.274000e+05
# Median selected monthly owner costs -with a mor...           1.847000e+03
# Median selected monthly owner costs -without a ...           7.130000e+02
# Median gross rent, 2013-2017                                 1.044000e+03
# Building permits, 2017                                       1.159500e+04
# Households, 2013-2017                                        1.956561e+06
# Persons per household, 2013-2017                             2.630000e+00
# Living in same house 1 year ago, percent of per...           8.680000e+01
# Language other than English spoken at home, per...           3.510000e+01
# Households with a computer, percent, 2013-2017               8.590000e+01
# ...                                                                   ...
# Bachelor's degree or higher, percent of persons...           3.720000e+01
# With a disability, under age 65 years, percent,...           6.600000e+00
# Persons  without health insurance, under age 65...           9.400000e+00
# In civilian labor force, total, percent of popu...           6.580000e+01
# In civilian labor force, female, percent of pop...           6.060000e+01
# Total accommodation and food services sales, 20...           1.455310e+07
# Total health care and social assistance receipt...           3.963987e+07
# Total manufacturers shipments, 2012 ($1,000)                 7.952698e+07
# Total merchant wholesaler sales, 2012 ($1,000)               1.008296e+08
# Total retail sales, 2012 ($1,000)                            6.276736e+07
# Total retail sales per capita, 2012                          1.199800e+04
# Mean travel time to work (minutes), workers age...           3.290000e+01
# Median household income (in 2017 dollars), 2013...           5.942600e+04
# Per capita income in past 12 months (in 2017 do...           3.372200e+04
# Persons in poverty, percent                                  1.460000e+01
# Total employer establishments, 2016                          1.331500e+05
# Total employment, 2016                                       2.401662e+06
# Total annual payroll, 2016 ($1,000)                          1.456801e+08
# Total employment, percent change, 2015-2016                  1.700000e+00
# Total nonemployer establishments, 2016                       4.837570e+05
# All firms, 2012                                              5.496860e+05
# Men-owned firms, 2012                                        2.912780e+05
# Women-owned firms, 2012                                      2.169290e+05
# Minority-owned firms, 2012                                   2.163740e+05
# Nonminority-owned firms, 2012                                3.191150e+05
# Veteran-owned firms, 2012                                    3.866500e+04
# Nonveteran-owned firms, 2012                                 4.954500e+05
# Population per square mile, 2010                             5.495100e+03
# Land area in square miles, 2010                              9.453300e+02
# FIPS Code                                                    1.703100e+04
#
#                                                     Travis County, Texas
# Fact
# Population estimates, July 1, 2017,  (V2017)                  1226698.00
# Population estimates base, April 1, 2010,  (V2017)            1024479.00
# Population, percent change - April 1, 2010 (est...                 19.70
# Population, Census, April 1, 2010                             1024266.00
# Persons under 5 years, percent                                      6.50
# Persons under 18 years, percent                                    22.10
# Persons 65 years and over, percent                                  9.60
# Female persons, percent                                            49.50
# White alone, percent                                               80.20
# Black or African American alone, percent                            8.90
# American Indian and Alaska Native alone, percent                    1.20
# Asian alone, percent                                                7.10
# Native Hawaiian and Other Pacific Islander alon...                  0.10
# Two or More Races, percent                                          2.60
# Hispanic or Latino, percent                                        33.90
# White alone, not Hispanic or Latino, percent                       49.00
# Veterans, 2013-2017                                             51893.00
# Foreign born persons, percent, 2013-2017                           17.80
# Housing units,  July 1, 2017,  (V2017)                         512388.00
# Owner-occupied housing unit rate, 2013-2017                        52.30
# Median value of owner-occupied housing units, 2...             275800.00
# Median selected monthly owner costs -with a mor...               1851.00
# Median selected monthly owner costs -without a ...                719.00
# Median gross rent, 2013-2017                                     1172.00
# Building permits, 2017                                          16729.00
# Households, 2013-2017                                          447561.00
# Persons per household, 2013-2017                                    2.58
# Living in same house 1 year ago, percent of per...                 80.50
# Language other than English spoken at home, per...                 31.60
# Households with a computer, percent, 2013-2017                     93.10
# ...                                                                  ...
# Bachelor's degree or higher, percent of persons...                 47.50
# With a disability, under age 65 years, percent,...                  6.40
# Persons  without health insurance, under age 65...                 15.20
# In civilian labor force, total, percent of popu...                 72.30
# In civilian labor force, female, percent of pop...                 65.60
# Total accommodation and food services sales, 20...            3726774.00
# Total health care and social assistance receipt...            6996844.00
# Total manufacturers shipments, 2012 ($1,000)                 12281855.00
# Total merchant wholesaler sales, 2012 ($1,000)               56614786.00
# Total retail sales, 2012 ($1,000)                            15583650.00
# Total retail sales per capita, 2012                             14224.00
# Mean travel time to work (minutes), workers age...                 25.30
# Median household income (in 2017 dollars), 2013...              68350.00
# Per capita income in past 12 months (in 2017 do...              38820.00
# Persons in poverty, percent                                        11.50
# Total employer establishments, 2016                             34547.00
# Total employment, 2016                                         582889.00
# Total annual payroll, 2016 ($1,000)                          34479460.00
# Total employment, percent change, 2015-2016                         3.50
# Total nonemployer establishments, 2016                         118984.00
# All firms, 2012                                                120533.00
# Men-owned firms, 2012                                           64679.00
# Women-owned firms, 2012                                         42186.00
# Minority-owned firms, 2012                                      35323.00
# Nonminority-owned firms, 2012                                   79883.00
# Veteran-owned firms, 2012                                        9520.00
# Nonveteran-owned firms, 2012                                   105236.00
# Population per square mile, 2010                                 1034.40
# Land area in square miles, 2010                                   990.20
# FIPS Code                                                       48453.00
#
# [62 rows x 7 columns]

# %%
# Remove extraneous rows, keep only Median Wages
wages_nonCA = non_ca_data[44:45]

#clean_ca.rename({"Median household income (in 2017 dollars), 2013-2017":"Median Income $"},axis=1)

wages_nonCA
# Out:
#                                                     San Francisco County, California  \
# Fact
# Median household income (in 2017 dollars), 2013...                           96265.0
#
#                                                     New York County (Manhattan Borough), New York  \
# Fact
# Median household income (in 2017 dollars), 2013...                                        79781.0
#
#                                                     King County, Washington  \
# Fact
# Median household income (in 2017 dollars), 2013...                  83571.0
#
#                                                     Multnomah County, Oregon  \
# Fact
# Median household income (in 2017 dollars), 2013...                   60369.0
#
#                                                     Kings County (Brooklyn Borough), New York  \
# Fact
# Median household income (in 2017 dollars), 2013...                                    52782.0
#
#                                                     Cook County, Illinois  \
# Fact
# Median household income (in 2017 dollars), 2013...                59426.0
#
#                                                     Travis County, Texas
# Fact
# Median household income (in 2017 dollars), 2013...               68350.0

# %%
# Now setup x and y axes for the bar plot

x2_data = wages_nonCA.columns.tolist()   #  x_data has the list of counties to be plotted
x2_axis = np.arange(len(x2_data))

print(x2_data)            # Check that this is a list of counties
print(wages_nonCA.values[0])   # this is accessing the first (and only) row of data


median_wage_nonCA = wages_nonCA.values[0]    #  [[1,2,3,4,5]] ->  row zero [0] [1,2,3,4,5]
# Out:
# ['San Francisco County, California', 'New York County (Manhattan Borough), New York', 'King County, Washington', 'Multnomah County, Oregon', 'Kings County (Brooklyn Borough), New York', 'Cook County, Illinois', 'Travis County, Texas']
# [96265. 79781. 83571. 60369. 52782. 59426. 68350.]

# %%
plt.bar(x2_axis, median_wage_nonCA, alpha=0.5, align="center")

tick_locations = [value for value in x2_axis]
#print(tick_locations)

plt.xticks(tick_locations, x2_data, rotation="35", ha='right')   #ha indicates the alignment of the xlabel with the tick mark
plt.xlim(-0.75, len(x2_axis)-0.25)
plt.ylim(0, max(median_wage) + 20000)
plt.title("Median Wages for People Leaving San Francisco County")
plt.xlabel("Comparison between SF and Top 5 non-CA counties")
plt.ylabel("Median Salary, ($)")

# Add labels to give more context 

style = dict(size=8, color ='black')
plt.text(0.4,120000, "US Census 2013-2017, All data shown in 2017 dollars", **style)
#plt.text(1,-70000, "All data shown in 2017 dollars", **style)
# Out:
# Text(0.4,120000,'US Census 2013-2017, All data shown in 2017 dollars')
